# %%
# Deleta imagens sem pares

import os

# Diretórios
x_dir = 'dataset/X/'
y_dir = 'dataset/y/'

# Obter listas de arquivos
x_files = set([f for f in os.listdir(x_dir) if f.endswith('.tif')])
y_files = set([f for f in os.listdir(y_dir) if f.endswith('.tif')])

# Encontrar arquivos sem pares
only_x = x_files - y_files
only_y = y_files - x_files

# Remover arquivos sem pares
print("Removendo arquivos sem pares:")
for f in only_x:
    path = os.path.join(x_dir, f)
    os.remove(path)
    print(f"Removido de X: {f}")

for f in only_y:
    path = os.path.join(y_dir, f)
    os.remove(path)
    print(f"Removido de Y: {f}")

print("\nOperação concluída. Verificando resultado:")

# Verificar resultado final
x_files_final = set([f for f in os.listdir(x_dir) if f.endswith('.tif')])
y_files_final = set([f for f in os.listdir(y_dir) if f.endswith('.tif')])

print(f"Total em X: {len(x_files_final)}")
print(f"Total em Y: {len(y_files_final)}")
print("Arquivos correspondentes:", x_files_final == y_files_final)
# Out:
# Removendo arquivos sem pares:
# Removido de X: 6057_tile_4.tif
# Removido de X: 5261_tile_2.tif
# Removido de X: 5658_tile_3.tif
# Removido de X: 4861_tile_4.tif
# Removido de X: 5458_tile_4.tif
# Removido de X: 5651_tile_2.tif
# Removido de X: 5659_tile_4.tif
# Removido de X: 5161_tile_2.tif
# Removido de X: 5058_tile_1.tif
# Removido de X: 5060_tile_1.tif
# Removido de X: 5154_tile_1.tif
# Removido de X: 5548_tile_4.tif
# Removido de X: 4556_tile_4.tif
# Removido de X: 4243_tile_1.tif
# Removido de X: 4553_tile_2.tif
# Removido de X: 4944_tile_4.tif
# Removido de X: 4735_tile_4.tif
# Removido de X: 4439_tile_1.tif
# Removido de X: 5652_tile_2.tif
# Removido de X: 4345_tile_1.tif
# Removido de X: 5548_tile_2.tif
# Removido de X: 5363_tile_3.tif
# Removido de X: 5758_tile_1.tif
# Removido de X: 4944_tile_1.tif
# Removido de X: 5359_tile_4.tif
# Removido de X: 5361_tile_3.tif
# Removido de X: 5361_tile_2.tif
# Removido de X: 5459_tile_3.tif
# Removido de X: 5560_tile_1.tif
# ...

# %%
import os
import torch
from torch.utils.data import Dataset, DataLoader, random_split
import rasterio
from torchvision import transforms
import torchvision
from tqdm import tqdm
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import itertools

torch.autograd.set_detect_anomaly(False)
torch.backends.cudnn.benchmark = True
torch.set_float32_matmul_precision('high')


IGNORE_INDEX = 255


def debug_single_sample(x_dir, y_dir):
    """
    Carrega e inspeciona a primeira imagem e máscara de um dataset para depuração.
    ESSENCIAL para verificar o tipo de dado (dtype) e a faixa de valores dos seus arquivos.
    """
    print("\n" + "="*50)
    print("=== INICIANDO DEPURAÇÃO DE DADOS DE ENTRADA ===")
    print("="*50)
    try:
        x_file = sorted([f for f in os.listdir(x_dir) if f.endswith('.tif')])[0]
        y_file = sorted([f for f in os.listdir(y_dir) if f.endswith('.tif')])[0]
        x_path = os.path.join(x_dir, x_file)
        y_path = os.path.join(y_dir, y_file)

        print(f"\n--- Inspecionando Imagem de Entrada (X): {x_file} ---")
        with rasterio.open(x_path) as src:
            print(f"Perfil do Rasterio (metadados): {src.profile}")
            x_raw = src.read()[:3]
        print(f"Tipo de Dado (dtype) do Numpy: {x_raw.dtype}")
        print(f"Shape do Array: {x_raw.shape}")
        print(f"Valores - Mínimo: {x_raw.min()}, Máximo: {x_raw.max()}, Média: {x_raw.mean():.2f}")

        print(f"\n--- Inspecionando Máscara (Y): {y_file} ---")
        with rasterio.open(y_path) as src:
            print(f"Perfil do Rasterio (metadados): {src.profile}")
            y_raw = src.read()
        print(f"Tipo de Dado (dtype) do Numpy: {y_raw.dtype}")
        print(f"Shape do Array: {y_raw.shape}")
        print(f"Valores únicos na máscara: {np.unique(y_raw)}")

    except Exception as e:
        print(f"\n!!! ERRO DURANTE A DEPURAÇÃO: {e} !!!")
    print("\n" + "="*50 + "\n=== FIM DA DEPURAÇÃO ===" + "\n" + "="*50 + "\n")


class SegmentationDataset(Dataset):
    def __init__(self, x_dir, y_dir, transform=None, ignore_index=255):
        self.x_dir = x_dir
        self.y_dir = y_dir
        self.transform = transform
        self.ignore_index = ignore_index
        self.x_files = sorted([f for f in os.listdir(x_dir) if f.endswith('.tif')])
        self.y_files = sorted([f for f in os.listdir(y_dir) if f.endswith('.tif')])
        assert len(self.x_files) == len(self.y_files), "Número de arquivos em X e Y não corresponde."

    def __len__(self):
        return len(self.x_files)

    def __getitem__(self, idx):
        x_path = os.path.join(self.x_dir, self.x_files[idx])
        y_path = os.path.join(self.y_dir, self.y_files[idx])
        
        try:
            with rasterio.open(x_path) as src:
                x_raw = src.read()[:3]
            
            with rasterio.open(y_path) as src:
                y_raw = src.read()

            x_raw = np.nan_to_num(x_raw, nan=0.0, posinf=0.0, neginf=0.0)
            x = x_raw.astype(np.float32) / 255.0
            x = np.clip(x, 0.0, 1.0)
            
            x = torch.from_numpy(x)

            if y_raw.ndim > 2 and y_raw.shape[0] > 1:
                y = np.argmax(y_raw, axis=0).astype(np.uint8)
                background_mask = np.sum(y_raw, axis=0) == 0
                y[background_mask] = self.ignore_index
            else:
                y = y_raw.squeeze()

            y = torch.from_numpy(y).long()
            
            if self.transform:
                x = self.transform(x)
            
            return x, y
        
        except Exception as e:
            print(f"ERRO ao processar o arquivo de índice {idx}: {self.x_files[idx]}")
            raise e


def prepare_datasets(x_dir, y_dir, val_split=0.15, test_split=0.15, random_seed=42):
    full_dataset = SegmentationDataset(
        x_dir=x_dir,
        y_dir=y_dir,
        transform=transforms.Compose([
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ]),
        ignore_index=IGNORE_INDEX
    )
    total_size = len(full_dataset)
    test_size = int(test_split * total_size)
    val_size = int(val_split * total_size)
    train_size = total_size - val_size - test_size
    
    train_dataset, val_dataset, test_dataset = random_split(
        full_dataset, [train_size, val_size, test_size],
        generator=torch.Generator().manual_seed(random_seed)
    )
    return train_dataset, val_dataset, test_dataset

def prepare_dataloaders(train_dataset, val_dataset, test_dataset, batch_size=8):
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
    return train_loader, val_loader, test_loader


def create_deeplabv3(output_channels=3):
    weights = torchvision.models.segmentation.DeepLabV3_ResNet50_Weights.DEFAULT
    model = torchvision.models.segmentation.deeplabv3_resnet50(weights=weights)
    model.classifier[4] = torch.nn.Conv2d(256, output_channels, kernel_size=(1, 1))
    if model.aux_classifier is not None:
        model.aux_classifier[4] = torch.nn.Conv2d(256, output_channels, kernel_size=(1, 1))
    return model


def get_color_map(device):
    color_map = torch.tensor([
        [0, 0, 0],       # Classe 0: Preto
        [0, 0, 255],     # Classe 1: Azul
        [0, 255, 0]      # Classe 2: Verde
    ], dtype=torch.uint8, device=device)
    return color_map

def map_to_rgb(tensor, color_map):
    rgb_image = torch.index_select(color_map, 0, tensor.flatten()).reshape(*tensor.shape, 3)
    return rgb_image.permute(2, 0, 1)

def log_images(writer, model, dataloader, epoch, num_images=4):
    model.eval()
    device = next(model.parameters()).device
    color_map = get_color_map(device)
    images_logged = 0
    with torch.no_grad():
        for inputs, masks in dataloader:
            inputs, masks = inputs.to(device), masks.to(device, non_blocking=True)
            outputs = model(inputs)['out']
            preds = torch.argmax(outputs, dim=1)
            
            mean = torch.tensor([0.485, 0.456, 0.406], device=device).view(1, 3, 1, 1)
            std = torch.tensor([0.229, 0.224, 0.225], device=device).view(1, 3, 1, 1)
            denorm_images = inputs * std + mean
            denorm_images = denorm_images.clamp(0, 1)
            
            for i in range(inputs.size(0)):
                if images_logged >= num_images:
                    model.train()
                    return
                
                img = denorm_images[i]
                mask_rgb = map_to_rgb(masks[i], color_map).float() / 255.0
                pred_rgb = map_to_rgb(preds[i], color_map).float() / 255.0
                
                comparison_grid = torchvision.utils.make_grid([img, mask_rgb, pred_rgb])
                writer.add_image(f'Validation/Comparison_{images_logged}', comparison_grid, epoch)
                images_logged += 1
    model.train()

def evaluate(model, dataloader, criterion, num_classes=3, ignore_index=255):
    model.eval()
    device = next(model.parameters()).device
    total_loss = 0.0
    intersection_per_class = torch.zeros(num_classes, device=device)
    union_per_class = torch.zeros(num_classes, device=device)
    
    with torch.no_grad():
        for inputs, masks in dataloader:
            inputs, masks = inputs.to(device), masks.to(device, non_blocking=True)
            outputs = model(inputs)['out']
            
            loss = criterion(outputs, masks)
            total_loss += loss.item()
            
            preds = torch.argmax(outputs, dim=1)
            
            valid_pixels = (masks != ignore_index)
            
            for c in range(num_classes):
                pred_mask = (preds == c) & valid_pixels
                true_mask = (masks == c) & valid_pixels
                intersection_per_class[c] += (pred_mask & true_mask).sum()
                union_per_class[c] += (pred_mask | true_mask).sum()

    iou_per_class = intersection_per_class / (union_per_class + 1e-8)
    mean_iou = iou_per_class.mean().item()
    avg_loss = total_loss / len(dataloader)
    
    model.train()
    return avg_loss, mean_iou


def train_with_validation(model, train_loader, val_loader, criterion, optimizer, hparam_name, num_epochs=50, patience=5):
    writer = SummaryWriter(log_dir=f'runs/deeplabv3/{hparam_name}')
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    scaler = torch.cuda.amp.GradScaler(enabled=(device.type == 'cuda'))
    
    print(f"Usando dispositivo: {device}")
    if device.type == 'cuda':
        print(f"GPU: {torch.cuda.get_device_name(0)}")
        
    best_iou = 0.0
    epochs_no_improve = 0
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        
        progress_bar = tqdm(train_loader, desc=f'Train Epoch {epoch+1}/{num_epochs}', leave=False)
        for inputs, masks in progress_bar:
            inputs, masks = inputs.to(device), masks.to(device, non_blocking=True)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.cuda.amp.autocast(enabled=(device.type == 'cuda')):
                outputs = model(inputs)['out']
                loss = criterion(outputs, masks)

            if torch.isnan(loss):
                print(f"!!! Perda NaN detectada na época {epoch+1}. Interrompendo este treino. !!!")
                print("Causa provável: taxa de aprendizado ainda muito alta ou problema nos dados não detectado.")
                writer.close()
                return model, True

            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            
            train_loss += loss.item()
            progress_bar.set_postfix(loss=f'{loss.item():.4f}')
        
        avg_train_loss = train_loss / len(train_loader)
        writer.add_scalar('Loss/train', avg_train_loss, epoch)
        
        # Passa o ignore_index para a função de avaliação
        val_loss, val_iou = evaluate(model, val_loader, criterion, ignore_index=IGNORE_INDEX)
        writer.add_scalar('Loss/val', val_loss, epoch)
        writer.add_scalar('IoU/val', val_iou, epoch)
        
        if (epoch + 1) % 5 == 0:
            log_images(writer, model, val_loader, epoch)
        
        print(f'Época {epoch+1}: Perda Treino: {avg_train_loss:.4f} | Perda Val: {val_loss:.4f} | IoU Val: {val_iou:.4f}')
        
        if val_iou > best_iou:
            best_iou = val_iou
            epochs_no_improve = 0
            torch.save(model.state_dict(), f'best_model_{hparam_name}.pth')
            print(f'Novo melhor modelo salvo com IoU: {best_iou:.4f}')
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f'Early stopping ativado após {epoch+1} épocas!')
                break
    
    writer.close()
    return model, False


if __name__ == "__main__":
    X_DIR = 'dataset/X/'
    Y_DIR = 'dataset/y/'
    
    debug_single_sample(x_dir=X_DIR, y_dir=Y_DIR)

    hyperparams = {
        'learning_rate': [5e-5, 1e-5],
        'weight_decay': [1e-4],
        'optimizer': ['AdamW', 'Adam']
    }
    
    keys, values = zip(*hyperparams.items())
    param_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
    
    print("Preparando datasets para todos os treinos...")
    train_ds, val_ds, test_ds = prepare_datasets(x_dir=X_DIR, y_dir=Y_DIR)
    train_loader, val_loader, test_loader = prepare_dataloaders(train_ds, val_ds, test_ds, batch_size=8)
    
    results = []
    
    for i, params in enumerate(param_combinations):
        hparam_name = f"lr={params['learning_rate']}_wd={params['weight_decay']}_opt={params['optimizer']}"
        print(f"\n=== Executando Combinação {i+1}/{len(param_combinations)}: {hparam_name} ===")
        
        model = create_deeplabv3(output_channels=3)
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        model.to(device)
        
        if params['optimizer'] == 'AdamW':
            optimizer = torch.optim.AdamW(model.parameters(), lr=params['learning_rate'], weight_decay=params['weight_decay'])
        else:
            optimizer = torch.optim.Adam(model.parameters(), lr=params['learning_rate'], weight_decay=params['weight_decay'])
            
        criterion = torch.nn.CrossEntropyLoss(ignore_index=IGNORE_INDEX)
        
        trained_model, failed = train_with_validation(
            model=model, train_loader=train_loader, val_loader=val_loader,
            criterion=criterion, optimizer=optimizer, hparam_name=hparam_name,
            num_epochs=50, patience=10
        )
        
        if failed:
            print("Pulando avaliação para esta combinação que falhou.")
            test_loss, test_iou = float('nan'), float('nan')
        else:
            print("Carregando melhor modelo para avaliação final no conjunto de teste...")
            trained_model.load_state_dict(torch.load(f'best_model_{hparam_name}.pth'))
            test_loss, test_iou = evaluate(trained_model, test_loader, criterion, ignore_index=IGNORE_INDEX)
            print(f'Resultado Final: Perda Teste: {test_loss:.4f} | IoU Teste: {test_iou:.4f}')
        
        results.append({'params': params, 'test_loss': test_loss, 'test_iou': test_iou})
    
    print("\n" + "="*25 + "\n=== Sumário dos Resultados ===\n" + "="*25)
    results.sort(key=lambda x: x['test_iou'], reverse=True)
    
    for i, res in enumerate(results):
        print(f"\n--- Rank {i+1} ---")
        print(f"Hiperparâmetros: {res['params']}")
        print(f"Perda Teste: {res['test_loss']:.4f} | IoU Teste: {res['test_iou']:.4f}")
    
    if results and not np.isnan(results[0]['test_iou']):
        best_result = results[0]
        print("\n" + "*"*30 + "\n=== Melhor Combinação Encontrada ===\n" + "*"*30)
        print(f"Hiperparâmetros: {best_result['params']}")
        print(f"IoU Teste: {best_result['test_iou']:.4f}")
        print("*"*30)
# Out:
# ...
# === INICIANDO DEPURAÇÃO DE DADOS DE ENTRADA ===
# ...
#
# --- Inspecionando Imagem de Entrada (X): 4244_tile_2.tif ---
# Perfil do Rasterio (metadados): {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 512, 'height': 512, 'count': 3, 'crs': CRS.from_wkt('PROJCS["SIRGAS 2000 / UTM zone 23S",GEOGCS["SIRGAS 2000",DATUM["Sistema_de_Referencia_Geocentrico_para_las_AmericaS_2000",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6674"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4674"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-45],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",10000000],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","31983"]]'), 'transform': Affine(0.8, 0.0, 598008.8,
# ...
