# %%
from torch.amp import autocast, GradScaler
import os
import torch
from torch.utils.data import Dataset, DataLoader, random_split
import rasterio
from torchvision import transforms
import torchvision
from tqdm import tqdm
import numpy as np
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime

torch.backends.cudnn.benchmark = True  # Acelera convoluções na GPU
torch.set_float32_matmul_precision('high')

# 1. Dataset Class (mesma que antes)
class SegmentationDataset(Dataset):
    def __init__(self, x_dir, y_dir, transform=None):
        self.x_dir = x_dir
        self.y_dir = y_dir
        self.transform = transform
        self.x_files = sorted([f for f in os.listdir(x_dir) if f.endswith('.tif')])
        self.y_files = sorted([f for f in os.listdir(y_dir) if f.endswith('.tif')])
        
        assert len(self.x_files) == len(self.y_files), "Número de arquivos em X e Y não corresponde"
        for x, y in zip(self.x_files, self.y_files):
            assert x == y, f"Arquivos não correspondentes: {x} vs {y}"

    def __len__(self):
        return len(self.x_files)

    def __getitem__(self, idx):
        x_path = os.path.join(self.x_dir, self.x_files[idx])
        y_path = os.path.join(self.y_dir, self.y_files[idx])
        
        with rasterio.open(x_path) as src:
            x = src.read()[:3]  # Garante 3 canais (RGB)
        
        with rasterio.open(y_path) as src:
            y = src.read()
        
        x = torch.from_numpy(x).float() / 255.0
        
        if y.shape[0] > 1:
            y = np.argmax(y, axis=0)
        y = torch.from_numpy(y).long()
        
        if self.transform:
            x = self.transform(x)
            
        return x, y


# 2. Divisão dos Dados
def prepare_datasets(x_dir, y_dir, val_split=0.15, test_split=0.15, random_seed=42):
    full_dataset = SegmentationDataset(
        x_dir=x_dir,
        y_dir=y_dir,
        transform=transforms.Compose([
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ])
    )
    
    # Calcula tamanhos
    total_size = len(full_dataset)
    test_size = int(test_split * total_size)
    val_size = int(val_split * total_size)
    train_size = total_size - val_size - test_size
    
    # Divide o dataset
    train_dataset, val_dataset, test_dataset = random_split(
        full_dataset,
        [train_size, val_size, test_size],
        generator=torch.Generator().manual_seed(random_seed)
    )
    
    return train_dataset, val_dataset, test_dataset

# 3. Preparação dos DataLoaders
def prepare_dataloaders(train_dataset, val_dataset, test_dataset, batch_size=8):
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=4)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4)
    
    return train_loader, val_loader, test_loader

# 4. Modelo
def create_deeplabv3(output_channels=3):
    weights = torchvision.models.segmentation.DeepLabV3_ResNet50_Weights.DEFAULT
    model = torchvision.models.segmentation.deeplabv3_resnet50(weights=weights)
    model.classifier[4] = torch.nn.Conv2d(256, output_channels, kernel_size=(1, 1))
    if model.aux_classifier is not None:
        model.aux_classifier[4] = torch.nn.Conv2d(256, output_channels, kernel_size=(1, 1))
    return model

# 5. Função para visualizar segmentações no TensorBoard
def log_images(writer, model, dataloader, epoch, num_images=3):
    model.eval()
    device = next(model.parameters()).device
    images_logged = 0
    
    with torch.no_grad():
        for inputs, masks in dataloader:
            inputs, masks = inputs.to(device), masks.to(device)
            outputs = model(inputs)['out']
            preds = torch.argmax(outputs, dim=1)
            
            # Denormalize images for visualization
            mean = torch.tensor([0.485, 0.456, 0.406]).view(1, 3, 1, 1).to(device)
            std = torch.tensor([0.229, 0.224, 0.225]).view(1, 3, 1, 1).to(device)
            denorm_images = inputs * std + mean
            denorm_images = denorm_images.clamp(0, 1)
            
            # Log images, masks and predictions
            for i in range(min(num_images - images_logged, inputs.size(0))):
                writer.add_image(f'Validation/Image_{images_logged}', denorm_images[i], epoch)
                
                # Convert masks and preds to RGB for visualization
                mask_rgb = torch.stack([masks[i]]*3, dim=0).float() / 2.0  # Simple colormap
                pred_rgb = torch.stack([preds[i]]*3, dim=0).float() / 2.0
                
                writer.add_image(f'Validation/GroundTruth_{images_logged}', mask_rgb, epoch)
                writer.add_image(f'Validation/Prediction_{images_logged}', pred_rgb, epoch)
                
                images_logged += 1
                if images_logged >= num_images:
                    return

# 6. Loop de Treinamento com Validação e Early Stopping
def train_with_validation(model, train_loader, val_loader, criterion, optimizer, num_epochs=50, patience=5):
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    writer = SummaryWriter(f'runs/deeplabv3_{timestamp}')
    
    best_iou = 0.0
    epochs_no_improve = 0
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    scaler = GradScaler(enabled=True)
    
    print(f"Usando dispositivo: {device}")
    if torch.cuda.is_available():
        print(f"Nome da GPU: {torch.cuda.get_device_name(0)}")
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        
        for inputs, masks in tqdm(train_loader, desc=f'Train Epoch {epoch+1}/{num_epochs}'):
            inputs, masks = inputs.to(device), masks.to(device)
            
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast(device_type='cuda', dtype=torch.float16):
                outputs = model(inputs)['out']
                loss = criterion(outputs, masks)
            
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            
            train_loss += loss.item()
        
        avg_train_loss = train_loss/len(train_loader)
        writer.add_scalar('Loss/train', avg_train_loss, epoch)
        
        val_loss, val_iou = evaluate(model, val_loader, criterion)
        writer.add_scalar('Loss/val', val_loss, epoch)
        writer.add_scalar('IoU/val', val_iou, epoch)
        
        if epoch % 5 == 0:
            log_images(writer, model, val_loader, epoch)
        
        print(f'Epoch {epoch+1}:')
        print(f'Train Loss: {avg_train_loss:.4f}')
        print(f'Val Loss: {val_loss:.4f} | Val IoU: {val_iou:.4f}')
        
        if val_iou > best_iou:
            best_iou = val_iou
            epochs_no_improve = 0
            torch.save(model.state_dict(), 'best_model.pth')
            print('Melhor modelo salvo!')
        else:
            epochs_no_improve += 1
            print(f'No improvement for {epochs_no_improve} epochs')
            
            if epochs_no_improve >= patience:
                print(f'Early stopping triggered after {epoch+1} epochs!')
                break
    
    writer.close()
    return model

# 7. Função de Avaliação (mesma que antes)
def evaluate(model, dataloader, criterion):
    model.eval()
    total_loss = 0.0
    total_iou = 0.0
    device = next(model.parameters()).device
    num_classes = 3  # Substitua pelo seu número real de classes
    
    with torch.no_grad():
        for inputs, masks in dataloader:
            inputs, masks = inputs.to(device), masks.to(device)
            outputs = model(inputs)['out']
            
            # Calcula loss
            loss = criterion(outputs, masks)
            total_loss += loss.item()
            
            # Calcula IoU para cada classe
            preds = torch.argmax(outputs, dim=1)
            
            for c in range(num_classes):
                pred_mask = (preds == c)
                true_mask = (masks == c)
                
                intersection = (pred_mask & true_mask).sum().float()
                union = (pred_mask | true_mask).sum().float()
                
                if union > 0:
                    total_iou += (intersection / union).item()
    
    avg_loss = total_loss / len(dataloader)
    avg_iou = total_iou / (len(dataloader) * num_classes)
    
    return avg_loss, avg_iou

import itertools

# 8. Fluxo Principal Modificado para Hyperparameter Tuning
if __name__ == "__main__":
    # Definir as combinações de hiperparâmetros
    hyperparams = {
        'learning_rate': [0.01, 0.001, 0.0001],
        'weight_decay': [0, 1e-4, 1e-5],
        'optimizer': ['Adam', 'SGD']
    }
    
    # Gerar todas as combinações possíveis (produto cartesiano)
    keys, values = zip(*hyperparams.items())
    param_combinations = [dict(zip(keys, v)) for v in itertools.product(*values)]
    
    # Selecionar 10 combinações aleatórias (ou as primeiras 10 se quiser todas)
    selected_combinations = param_combinations[:10]
    
    # Preparar dados (uma vez para todas as execuções)
    train_ds, val_ds, test_ds = prepare_datasets(
        x_dir='dataset/X/',
        y_dir='dataset/y/',
        val_split=0.15,
        test_split=0.15
    )
    
    train_loader, val_loader, test_loader = prepare_dataloaders(train_ds, val_ds, test_ds, batch_size=8)
    
    # Resultados serão armazenados aqui
    results = []
    
    for i, params in enumerate(selected_combinations):
        print(f"\n=== Executando combinação {i+1}/10 ===")
        print("Hiperparâmetros:", params)
        
        # Criar modelo
        model = create_deeplabv3(output_channels=3)
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        model = model.to(device)
        
        # Definir otimização com os hiperparâmetros atuais
        if params['optimizer'] == 'Adam':
            optimizer = torch.optim.Adam(
                model.parameters(), 
                lr=params['learning_rate'],
                weight_decay=params['weight_decay']
            )
        else:  # SGD
            optimizer = torch.optim.SGD(
                model.parameters(), 
                lr=params['learning_rate'],
                weight_decay=params['weight_decay'],
                momentum=0.9
            )
            
        criterion = torch.nn.CrossEntropyLoss()
        
        # Treinar com early stopping
        trained_model = train_with_validation(
            model=model,
            train_loader=train_loader,
            val_loader=val_loader,
            criterion=criterion,
            optimizer=optimizer,
            num_epochs=25,
            patience=5
        )
        
        # Avaliar no teste
        test_loss, test_iou = evaluate(trained_model, test_loader, criterion)
        print(f'Resultado: Test Loss: {test_loss:.4f} | Test IoU: {test_iou:.4f}')
        
        # Armazenar resultados
        results.append({
            'params': params,
            'test_loss': test_loss,
            'test_iou': test_iou
        })
    
    # Exibir resumo dos resultados
    print("\n=== Resumo dos Resultados ===")
    for i, res in enumerate(results):
        print(f"Combinação {i+1}:")
        print(f"Hiperparâmetros: {res['params']}")
        print(f"Test Loss: {res['test_loss']:.4f} | Test IoU: {res['test_iou']:.4f}")
        print("-" * 50)
    
    # Encontrar a melhor combinação
    best_result = max(results, key=lambda x: x['test_iou'])
    print("\n=== Melhor Combinação ===")
    print(f"Hiperparâmetros: {best_result['params']}")
    print(f"Test IoU: {best_result['test_iou']:.4f}")

# %% [markdown]
# ## Inferência

# %%
import os
import torch
import rasterio
from torchvision import transforms
import numpy as np
import torchvision

# Configurações
X_DIR = 'TILES/'  # Pasta com imagens de entrada
OUTPUT_DIR = 'INFERENCIA/'  # Pasta para salvar as predições em grayscale
MODEL_PATH = 'best_model.pth'  # Caminho para o melhor modelo salvo
NUM_CLASSES = 3  # Número de classes no seu modelo

# Criar pasta de saída
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Dispositivo (GPU se disponível)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Usando dispositivo: {device}")

# Carregar modelo
def create_deeplabv3(output_channels=3):
    weights = torchvision.models.segmentation.DeepLabV3_ResNet50_Weights.DEFAULT
    model = torchvision.models.segmentation.deeplabv3_resnet50(weights=weights)
    model.classifier[4] = torch.nn.Conv2d(256, output_channels, kernel_size=(1, 1))
    if model.aux_classifier is not None:
        model.aux_classifier[4] = torch.nn.Conv2d(256, output_channels, kernel_size=(1, 1))
    return model

model = create_deeplabv3(output_channels=NUM_CLASSES)
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
model = model.to(device)
model.eval()

# Transformações
transform = transforms.Compose([
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Processar cada imagem
for filename in os.listdir(X_DIR):
    if filename.endswith('.tif'):
        input_path = os.path.join(X_DIR, filename)
        output_path = os.path.join(OUTPUT_DIR, filename)
        
        print(f"Processando: {filename}")
        
        # Carregar imagem
        with rasterio.open(input_path) as src:
            x = src.read()[:3]  # Pega apenas os 3 primeiros canais (RGB)
            meta = src.meta.copy()
        
        # Atualizar metadados para imagem de saída (1 banda, grayscale)
        meta.update({
            'count': 1,
            'dtype': 'uint8'
        })
        
        # Pré-processamento
        x = torch.from_numpy(x).float() / 255.0
        x = transform(x)
        x = x.unsqueeze(0).to(device)
        
        # Inferência
        with torch.no_grad():
            output = model(x)['out']
            pred = torch.argmax(output, dim=1).squeeze().cpu().numpy()
        
        # Converter predições para uint8 (0-255)
        pred_gray = pred.astype(np.uint8)
        
        # Salvar TIFF grayscale georreferenciado
        with rasterio.open(output_path, 'w', **meta) as dst:
            dst.write(pred_gray, 1)  # Escreve na banda 1

print("Inferência concluída! Arquivos em grayscale salvos em:", OUTPUT_DIR)
# Out:
# Usando dispositivo: cuda
# Processando: MOSAICO_2015_tile_1000.tif
# Processando: MOSAICO_2015_tile_1001.tif
# Processando: MOSAICO_2015_tile_1002.tif
# Processando: MOSAICO_2015_tile_1003.tif
# Processando: MOSAICO_2015_tile_1004.tif
# Processando: MOSAICO_2015_tile_10049.tif
# Processando: MOSAICO_2015_tile_1005.tif
# Processando: MOSAICO_2015_tile_10050.tif
# Processando: MOSAICO_2015_tile_10051.tif
# Processando: MOSAICO_2015_tile_10052.tif
# Processando: MOSAICO_2015_tile_10053.tif
# Processando: MOSAICO_2015_tile_10054.tif
# Processando: MOSAICO_2015_tile_10055.tif
# Processando: MOSAICO_2015_tile_10056.tif
# Processando: MOSAICO_2015_tile_10057.tif
# Processando: MOSAICO_2015_tile_10058.tif
# Processando: MOSAICO_2015_tile_10059.tif
# Processando: MOSAICO_2015_tile_1006.tif
# Processando: MOSAICO_2015_tile_10060.tif
# Processando: MOSAICO_2015_tile_10061.tif
# Processando: MOSAICO_2015_tile_10062.tif
# Processando: MOSAICO_2015_tile_10063.tif
# Processando: MOSAICO_2015_tile_10064.tif
# Processando: MOSAICO_2015_tile_10065.tif
# Processando: MOSAICO_2015_tile_10066.tif
# Processando: MOSAICO_2015_tile_10067.tif
# Processando: MOSAICO_2015_tile_10068.tif
# Processando: MOSAICO_2015_tile_10069.tif
# Processando: MOSAICO_2015_tile_1007.tif
# Processando: MOSAICO_2015_tile_10070.tif
# Processando: MOSAICO_2015_tile_10071.tif
# Processando: MOSAICO_2015_tile_10072.tif
# Processando: MOSAICO_2015_tile_10073.tif
# Processando: MOSAICO_2015_tile_10074.tif
# Processando: MOSAICO_2015_tile_10075.tif
# Processando: MOSAICO_2015_tile_10076.tif
# Processando: MOSAICO_2015_tile_10077.tif
# Processando: MOSAICO_2015_tile_10078.tif
# Processando: MOSAICO_2015_tile_10079.tif
# Processando: MOSAICO_2015_tile_1008.tif
# Processando: MOSAICO_2015_tile_10080.tif
# Processando: MOSAICO_2015_tile_10081.tif
# Processando: MOSAICO_2015_tile_10082.tif
# Processando: MOSAICO_2015_tile_10083.tif
# Processando: MOSAICO_2015_tile_10084.tif
# Processando: MOSAICO_2015_tile_10085.tif
# Processando: MOSAICO_2015_tile_10086.tif
# Processando: MOSAICO_2015_tile_10087.tif
# Processando: MOSAICO_2015_tile_10088.tif
# Processando: MOSAICO_2015_tile_10089.tif
# Processando: MOSAICO_2015_tile_1009.tif
# Processando: MOSAICO_2015_tile_10090.tif
# Processando: MOSAICO_2015_tile_10091.tif
# Processando: MOSAICO_2015_tile_10092.tif
# Processando: MOSAICO_2015_tile_10093.tif
# Processando: MOSAICO_2015_tile_10094.tif
# Processando: MOSAICO_2015_tile_10095.tif
# Processando: MOSAICO_2015_tile_10096.tif
# Processando: MOSAICO_2015_tile_10097.tif
# Processando: MOSAICO_2015_tile_10098.tif
# Processando: MOSAICO_2015_tile_10099.tif
# Processando: MOSAICO_2015_tile_1010.tif
# Processando: MOSAICO_2015_tile_10100.tif
# Processando: MOSAICO_2015_tile_10101.tif
# Processando: MOSAICO_2015_tile_10102.tif
# Processando: MOSAICO_2015_tile_10103.tif
# Processando: MOSAICO_2015_tile_10104.tif
# Processando: MOSAICO_2015_tile_10105.tif
# Processando: MOSAICO_2015_tile_10106.tif
# Processando: MOSAICO_2015_tile_10107.tif
# Processando: MOSAICO_2015_tile_10108.tif
# Processando: MOSAICO_2015_tile_10109.tif
# Processando: MOSAICO_2015_tile_1011.tif
# Processando: MOSAICO_2015_tile_10110.tif
# Processando: MOSAICO_2015_tile_10111.tif
# Processando: MOSAICO_2015_tile_10112.tif
# Processando: MOSAICO_2015_tile_10113.tif
# Processando: MOSAICO_2015_tile_10114.tif
# Processando: MOSAICO_2015_tile_10115.tif
# Processando: MOSAICO_2015_tile_10116.tif
# Processando: MOSAICO_2015_tile_10117.tif
# Processando: MOSAICO_2015_tile_10118.tif
# Processando: MOSAICO_2015_tile_10119.tif
# Processando: MOSAICO_2015_tile_1012.tif
# Processando: MOSAICO_2015_tile_10120.tif
# Processando: MOSAICO_2015_tile_10121.tif
# Processando: MOSAICO_2015_tile_10122.tif
# Processando: MOSAICO_2015_tile_10123.tif
# Processando: MOSAICO_2015_tile_10124.tif
# Processando: MOSAICO_2015_tile_10125.tif
# Processando: MOSAICO_2015_tile_10126.tif
# Processando: MOSAICO_2015_tile_10127.tif
# Processando: MOSAICO_2015_tile_10128.tif
# Processando: MOSAICO_2015_tile_10129.tif
# Processando: MOSAICO_2015_tile_1013.tif
# Processando: MOSAICO_2015_tile_10130.tif
# Processando: MOSAICO_2015_tile_10131.tif
# Processando: MOSAICO_2015_tile_10132.tif
# Processando: MOSAICO_2015_tile_10133.tif
# Processando: MOSAICO_2015_tile_10134.tif
# Processando: MOSAICO_2015_tile_10135.tif
# Processando: MOSAICO_2015_tile_10136.tif
# Processando: MOSAICO_2015_tile_10137.tif
# Processando: MOSAICO_2015_tile_10138.tif
# Processando: MOSAICO_2015_tile_10139.tif
# Processando: MOSAICO_2015_tile_1014.tif
# Processando: MOSAICO_2015_tile_10140.tif
# Processando: MOSAICO_2015_tile_10141.tif
# Processando: MOSAICO_2015_tile_10142.tif
# Processando: MOSAICO_2015_tile_10143.tif
# Processando: MOSAICO_2015_tile_10144.tif
# Processando: MOSAICO_2015_tile_10145.tif
# Processando: MOSAICO_2015_tile_10146.tif
# Processando: MOSAICO_2015_tile_10147.tif
# Processando: MOSAICO_2015_tile_10148.tif
# Processando: MOSAICO_2015_tile_10149.tif
# Processando: MOSAICO_2015_tile_1015.tif
# Processando: MOSAICO_2015_tile_10150.tif
# Processando: MOSAICO_2015_tile_10151.tif
# Processando: MOSAICO_2015_tile_10152.tif
# Processando: MOSAICO_2015_tile_10153.tif
# Processando: MOSAICO_2015_tile_10154.tif
# Processando: MOSAICO_2015_tile_10155.tif
# Processando: MOSAICO_2015_tile_10156.tif
# Processando: MOSAICO_2015_tile_10157.tif
# Processando: MOSAICO_2015_tile_10158.tif
# Processando: MOSAICO_2015_tile_10159.tif
# Processando: MOSAICO_2015_tile_1016.tif
# Processando: MOSAICO_2015_tile_10160.tif
# Processando: MOSAICO_2015_tile_10161.tif
# Processando: MOSAICO_2015_tile_10162.tif
# Processando: MOSAICO_2015_tile_10163.tif
# Processando: MOSAICO_2015_tile_10164.tif
# Processando: MOSAICO_2015_tile_10165.tif
# Processando: MOSAICO_2015_tile_10166.tif
# Processando: MOSAICO_2015_tile_10167.tif
# Processando: MOSAICO_2015_tile_10168.tif
# Processando: MOSAICO_2015_tile_10169.tif
# Processando: MOSAICO_2015_tile_1017.tif
# Processando: MOSAICO_2015_tile_10170.tif
# Processando: MOSAICO_2015_tile_10171.tif
# Processando: MOSAICO_2015_tile_10172.tif
# Processando: MOSAICO_2015_tile_10173.tif
# Processando: MOSAICO_2015_tile_10174.tif
# Processando: MOSAICO_2015_tile_10175.tif
# Processando: MOSAICO_2015_tile_10176.tif
# Processando: MOSAICO_2015_tile_10177.tif
# Processando: MOSAICO_2015_tile_10178.tif
# Processando: MOSAICO_2015_tile_10179.tif
# Processando: MOSAICO_2015_tile_10180.tif
# Processando: MOSAICO_2015_tile_10181.tif
# Processando: MOSAICO_2015_tile_10182.tif
# Processando: MOSAICO_2015_tile_10183.tif
# Processando: MOSAICO_2015_tile_10184.tif
# Processando: MOSAICO_2015_tile_10185.tif
# Processando: MOSAICO_2015_tile_10186.tif
# Processando: MOSAICO_2015_tile_10187.tif
# Processando: MOSAICO_2015_tile_10188.tif
# Processando: MOSAICO_2015_tile_10189.tif
# Processando: MOSAICO_2015_tile_10190.tif
# Processando: MOSAICO_2015_tile_10271.tif
# Processando: MOSAICO_2015_tile_10272.tif
# Processando: MOSAICO_2015_tile_10273.tif
# Processando: MOSAICO_2015_tile_10274.tif
# Processando: MOSAICO_2015_tile_10275.tif
# Processando: MOSAICO_2015_tile_10276.tif
# Processando: MOSAICO_2015_tile_10277.tif
# Processando: MOSAICO_2015_tile_10278.tif
# Processando: MOSAICO_2015_tile_10279.tif
# Processando: MOSAICO_2015_tile_10280.tif
# Processando: MOSAICO_2015_tile_10281.tif
# Processando: MOSAICO_2015_tile_10282.tif
# Processando: MOSAICO_2015_tile_10283.tif
# Processando: MOSAICO_2015_tile_10284.tif
# Processando: MOSAICO_2015_tile_10285.tif
# Processando: MOSAICO_2015_tile_10286.tif
# Processando: MOSAICO_2015_tile_10287.tif
# Processando: MOSAICO_2015_tile_10288.tif
# Processando: MOSAICO_2015_tile_10289.tif
# Processando: MOSAICO_2015_tile_10290.tif
# Processando: MOSAICO_2015_tile_10291.tif
# Processando: MOSAICO_2015_tile_10292.tif
# Processando: MOSAICO_2015_tile_10293.tif
# Processando: MOSAICO_2015_tile_10294.tif
# Processando: MOSAICO_2015_tile_10295.tif
# Processando: MOSAICO_2015_tile_10296.tif
# Processando: MOSAICO_2015_tile_10297.tif
# Processando: MOSAICO_2015_tile_10298.tif
# Processando: MOSAICO_2015_tile_10299.tif
# Processando: MOSAICO_2015_tile_10300.tif
# Processando: MOSAICO_2015_tile_10301.tif
# Processando: MOSAICO_2015_tile_10302.tif
# Processando: MOSAICO_2015_tile_10303.tif
# Processando: MOSAICO_2015_tile_10304.tif
# Processando: MOSAICO_2015_tile_10305.tif
# Processando: MOSAICO_2015_tile_10306.tif
# Processando: MOSAICO_2015_tile_10307.tif
# Processando: MOSAICO_2015_tile_10308.tif
# Processando: MOSAICO_2015_tile_10309.tif
# Processando: MOSAICO_2015_tile_10310.tif
# Processando: MOSAICO_2015_tile_10311.tif
# Processando: MOSAICO_2015_tile_10312.tif
# Processando: MOSAICO_2015_tile_10313.tif
# Processando: MOSAICO_2015_tile_10314.tif
# Processando: MOSAICO_2015_tile_10315.tif
# Processando: MOSAICO_2015_tile_10316.tif
# Processando: MOSAICO_2015_tile_10317.tif
# Processando: MOSAICO_2015_tile_10318.tif
# Processando: MOSAICO_2015_tile_10319.tif
# Processando: MOSAICO_2015_tile_10320.tif
# Processando: MOSAICO_2015_tile_10321.tif
# Processando: MOSAICO_2015_tile_10322.tif
# Processando: MOSAICO_2015_tile_10323.tif
# Processando: MOSAICO_2015_tile_10324.tif
# Processando: MOSAICO_2015_tile_10325.tif
# Processando: MOSAICO_2015_tile_10326.tif
# Processando: MOSAICO_2015_tile_10327.tif
# Processando: MOSAICO_2015_tile_10328.tif
# Processando: MOSAICO_2015_tile_10329.tif
# Processando: MOSAICO_2015_tile_10330.tif
# Processando: MOSAICO_2015_tile_10331.tif
# Processando: MOSAICO_2015_tile_10332.tif
# Processando: MOSAICO_2015_tile_10333.tif
# Processando: MOSAICO_2015_tile_10334.tif
# Processando: MOSAICO_2015_tile_10335.tif
# Processando: MOSAICO_2015_tile_10336.tif
# Processando: MOSAICO_2015_tile_10337.tif
# Processando: MOSAICO_2015_tile_10338.tif
# Processando: MOSAICO_2015_tile_10339.tif
# Processando: MOSAICO_2015_tile_10340.tif
# Processando: MOSAICO_2015_tile_10341.tif
# Processando: MOSAICO_2015_tile_10342.tif
# Processando: MOSAICO_2015_tile_10343.tif
# Processando: MOSAICO_2015_tile_10344.tif
# Processando: MOSAICO_2015_tile_10345.tif
# Processando: MOSAICO_2015_tile_10346.tif
# Processando: MOSAICO_2015_tile_10347.tif
# Processando: MOSAICO_2015_tile_10348.tif
# Processando: MOSAICO_2015_tile_10349.tif
# Processando: MOSAICO_2015_tile_10350.tif
# Processando: MOSAICO_2015_tile_10351.tif
# Processando: MOSAICO_2015_tile_10352.tif
# Processando: MOSAICO_2015_tile_10353.tif
# Processando: MOSAICO_2015_tile_10354.tif
# Processando: MOSAICO_2015_tile_10355.tif
# Processando: MOSAICO_2015_tile_10356.tif
# Processando: MOSAICO_2015_tile_10357.tif
# Processando: MOSAICO_2015_tile_10358.tif
# Processando: MOSAICO_2015_tile_10359.tif
# Processando: MOSAICO_2015_tile_10360.tif
# Processando: MOSAICO_2015_tile_10361.tif
# Processando: MOSAICO_2015_tile_10362.tif
# Processando: MOSAICO_2015_tile_10363.tif
# Processando: MOSAICO_2015_tile_10364.tif
# Processando: MOSAICO_2015_tile_10365.tif
# Processando: MOSAICO_2015_tile_10366.tif
# Processando: MOSAICO_2015_tile_10367.tif
# Processando: MOSAICO_2015_tile_10368.tif
# Processando: MOSAICO_2015_tile_10369.tif
# Processando: MOSAICO_2015_tile_10370.tif
# Processando: MOSAICO_2015_tile_10371.tif
# Processando: MOSAICO_2015_tile_10372.tif
# Processando: MOSAICO_2015_tile_10373.tif
# Processando: MOSAICO_2015_tile_10374.tif
# Processando: MOSAICO_2015_tile_10375.tif
# Processando: MOSAICO_2015_tile_10376.tif
# Processando: MOSAICO_2015_tile_10377.tif
# Processando: MOSAICO_2015_tile_10378.tif
# Processando: MOSAICO_2015_tile_10379.tif
# Processando: MOSAICO_2015_tile_10380.tif
# Processando: MOSAICO_2015_tile_10381.tif
# Processando: MOSAICO_2015_tile_10382.tif
# Processando: MOSAICO_2015_tile_10383.tif
# Processando: MOSAICO_2015_tile_10384.tif
# Processando: MOSAICO_2015_tile_10385.tif
# Processando: MOSAICO_2015_tile_10386.tif
# Processando: MOSAICO_2015_tile_10387.tif
# Processando: MOSAICO_2015_tile_10388.tif
# Processando: MOSAICO_2015_tile_10389.tif
# Processando: MOSAICO_2015_tile_10390.tif
# Processando: MOSAICO_2015_tile_10391.tif
# Processando: MOSAICO_2015_tile_10392.tif
# Processando: MOSAICO_2015_tile_10393.tif
# Processando: MOSAICO_2015_tile_10394.tif
# Processando: MOSAICO_2015_tile_10395.tif
# Processando: MOSAICO_2015_tile_10396.tif
# Processando: MOSAICO_2015_tile_10397.tif
# Processando: MOSAICO_2015_tile_10398.tif
# Processando: MOSAICO_2015_tile_10399.tif
# Processando: MOSAICO_2015_tile_10400.tif
# Processando: MOSAICO_2015_tile_10401.tif
# Processando: MOSAICO_2015_tile_10402.tif
# Processando: MOSAICO_2015_tile_10403.tif
# Processando: MOSAICO_2015_tile_10404.tif
# Processando: MOSAICO_2015_tile_10405.tif
# Processando: MOSAICO_2015_tile_10406.tif
# Processando: MOSAICO_2015_tile_10407.tif
# Processando: MOSAICO_2015_tile_10408.tif
# Processando: MOSAICO_2015_tile_10409.tif
# Processando: MOSAICO_2015_tile_10410.tif
# Processando: MOSAICO_2015_tile_10411.tif
# Processando: MOSAICO_2015_tile_10412.tif
# Processando: MOSAICO_2015_tile_10493.tif
# Processando: MOSAICO_2015_tile_10494.tif
# Processando: MOSAICO_2015_tile_10495.tif
# Processando: MOSAICO_2015_tile_10496.tif
# Processando: MOSAICO_2015_tile_10497.tif
# Processando: MOSAICO_2015_tile_10498.tif
# Processando: MOSAICO_2015_tile_10499.tif
# Processando: MOSAICO_2015_tile_10500.tif
# Processando: MOSAICO_2015_tile_10501.tif
# Processando: MOSAICO_2015_tile_10502.tif
# Processando: MOSAICO_2015_tile_10503.tif
# Processando: MOSAICO_2015_tile_10504.tif
# Processando: MOSAICO_2015_tile_10505.tif
# Processando: MOSAICO_2015_tile_10506.tif
# Processando: MOSAICO_2015_tile_10507.tif
# Processando: MOSAICO_2015_tile_10508.tif
# Processando: MOSAICO_2015_tile_10509.tif
# Processando: MOSAICO_2015_tile_10510.tif
# Processando: MOSAICO_2015_tile_10511.tif
# Processando: MOSAICO_2015_tile_10512.tif
# Processando: MOSAICO_2015_tile_10513.tif
# Processando: MOSAICO_2015_tile_10514.tif
# Processando: MOSAICO_2015_tile_10515.tif
# Processando: MOSAICO_2015_tile_10516.tif
# Processando: MOSAICO_2015_tile_10517.tif
# Processando: MOSAICO_2015_tile_10518.tif
# Processando: MOSAICO_2015_tile_10519.tif
# Processando: MOSAICO_2015_tile_10520.tif
# Processando: MOSAICO_2015_tile_10521.tif
# Processando: MOSAICO_2015_tile_10522.tif
# Processando: MOSAICO_2015_tile_10523.tif
# Processando: MOSAICO_2015_tile_10524.tif
# Processando: MOSAICO_2015_tile_10525.tif
# Processando: MOSAICO_2015_tile_10526.tif
# Processando: MOSAICO_2015_tile_10527.tif
# Processando: MOSAICO_2015_tile_10528.tif
# Processando: MOSAICO_2015_tile_10529.tif
# Processando: MOSAICO_2015_tile_10530.tif
# Processando: MOSAICO_2015_tile_10531.tif
# Processando: MOSAICO_2015_tile_10532.tif
# Processando: MOSAICO_2015_tile_10533.tif
# Processando: MOSAICO_2015_tile_10534.tif
# Processando: MOSAICO_2015_tile_10535.tif
# Processando: MOSAICO_2015_tile_10536.tif
# Processando: MOSAICO_2015_tile_10537.tif
# Processando: MOSAICO_2015_tile_10538.tif
# Processando: MOSAICO_2015_tile_10539.tif
# Processando: MOSAICO_2015_tile_10540.tif
# Processando: MOSAICO_2015_tile_10541.tif
# Processando: MOSAICO_2015_tile_10542.tif
# Processando: MOSAICO_2015_tile_10543.tif
# Processando: MOSAICO_2015_tile_10544.tif
# Processando: MOSAICO_2015_tile_10545.tif
# Processando: MOSAICO_2015_tile_10546.tif
# Processando: MOSAICO_2015_tile_10547.tif
# Processando: MOSAICO_2015_tile_10548.tif
# Processando: MOSAICO_2015_tile_10549.tif
# Processando: MOSAICO_2015_tile_10550.tif
# Processando: MOSAICO_2015_tile_10551.tif
# Processando: MOSAICO_2015_tile_10552.tif
# Processando: MOSAICO_2015_tile_10553.tif
# Processando: MOSAICO_2015_tile_10554.tif
# Processando: MOSAICO_2015_tile_10555.tif
# Processando: MOSAICO_2015_tile_10556.tif
# Processando: MOSAICO_2015_tile_10557.tif
# Processando: MOSAICO_2015_tile_10558.tif
# Processando: MOSAICO_2015_tile_10559.tif
# Processando: MOSAICO_2015_tile_10560.tif
# Processando: MOSAICO_2015_tile_10561.tif
# Processando: MOSAICO_2015_tile_10562.tif
# Processando: MOSAICO_2015_tile_10563.tif
# Processando: MOSAICO_2015_tile_10564.tif
# Processando: MOSAICO_2015_tile_10565.tif
# Processando: MOSAICO_2015_tile_10566.tif
# Processando: MOSAICO_2015_tile_10567.tif
# Processando: MOSAICO_2015_tile_10568.tif
# Processando: MOSAICO_2015_tile_10569.tif
# Processando: MOSAICO_2015_tile_10570.tif
# Processando: MOSAICO_2015_tile_10571.tif
# Processando: MOSAICO_2015_tile_10572.tif
# Processando: MOSAICO_2015_tile_10573.tif
# Processando: MOSAICO_2015_tile_10574.tif
# Processando: MOSAICO_2015_tile_10575.tif
# Processando: MOSAICO_2015_tile_10576.tif
# Processando: MOSAICO_2015_tile_10577.tif
# Processando: MOSAICO_2015_tile_10578.tif
# Processando: MOSAICO_2015_tile_10579.tif
# Processando: MOSAICO_2015_tile_10580.tif
# Processando: MOSAICO_2015_tile_10581.tif
# Processando: MOSAICO_2015_tile_10582.tif
# Processando: MOSAICO_2015_tile_10583.tif
# Processando: MOSAICO_2015_tile_10584.tif
# Processando: MOSAICO_2015_tile_10585.tif
# Processando: MOSAICO_2015_tile_10586.tif
# Processando: MOSAICO_2015_tile_10587.tif
# Processando: MOSAICO_2015_tile_10588.tif
# Processando: MOSAICO_2015_tile_10589.tif
# Processando: MOSAICO_2015_tile_10590.tif
# Processando: MOSAICO_2015_tile_10591.tif
# Processando: MOSAICO_2015_tile_10592.tif
# Processando: MOSAICO_2015_tile_10593.tif
# Processando: MOSAICO_2015_tile_10594.tif
# Processando: MOSAICO_2015_tile_10595.tif
# Processando: MOSAICO_2015_tile_10596.tif
# Processando: MOSAICO_2015_tile_10597.tif
# Processando: MOSAICO_2015_tile_10598.tif
# Processando: MOSAICO_2015_tile_10599.tif
# Processando: MOSAICO_2015_tile_106.tif
# Processando: MOSAICO_2015_tile_10600.tif
# Processando: MOSAICO_2015_tile_10601.tif
# Processando: MOSAICO_2015_tile_10602.tif
# Processando: MOSAICO_2015_tile_10603.tif
# Processando: MOSAICO_2015_tile_10604.tif
# Processando: MOSAICO_2015_tile_10605.tif
# Processando: MOSAICO_2015_tile_10606.tif
# Processando: MOSAICO_2015_tile_10607.tif
# Processando: MOSAICO_2015_tile_10608.tif
# Processando: MOSAICO_2015_tile_10609.tif
# Processando: MOSAICO_2015_tile_10610.tif
# Processando: MOSAICO_2015_tile_10611.tif
# Processando: MOSAICO_2015_tile_10612.tif
# Processando: MOSAICO_2015_tile_10613.tif
# Processando: MOSAICO_2015_tile_10614.tif
# Processando: MOSAICO_2015_tile_10615.tif
# Processando: MOSAICO_2015_tile_10616.tif
# Processando: MOSAICO_2015_tile_10617.tif
# Processando: MOSAICO_2015_tile_10618.tif
# Processando: MOSAICO_2015_tile_10619.tif
# Processando: MOSAICO_2015_tile_10620.tif
# Processando: MOSAICO_2015_tile_10621.tif
# Processando: MOSAICO_2015_tile_10622.tif
# Processando: MOSAICO_2015_tile_10623.tif
# Processando: MOSAICO_2015_tile_10624.tif
# Processando: MOSAICO_2015_tile_10625.tif
# Processando: MOSAICO_2015_tile_10626.tif
# Processando: MOSAICO_2015_tile_10627.tif
# Processando: MOSAICO_2015_tile_10628.tif
# Processando: MOSAICO_2015_tile_10629.tif
# Processando: MOSAICO_2015_tile_10630.tif
# Processando: MOSAICO_2015_tile_10631.tif
# Processando: MOSAICO_2015_tile_10632.tif
# Processando: MOSAICO_2015_tile_10633.tif
# Processando: MOSAICO_2015_tile_10634.tif
# Processando: MOSAICO_2015_tile_107.tif
# Processando: MOSAICO_2015_tile_10710.tif
# Processando: MOSAICO_2015_tile_10711.tif
# Processando: MOSAICO_2015_tile_10712.tif
# Processando: MOSAICO_2015_tile_10713.tif
# Processando: MOSAICO_2015_tile_10714.tif
# Processando: MOSAICO_2015_tile_10715.tif
# Processando: MOSAICO_2015_tile_10716.tif
# Processando: MOSAICO_2015_tile_10717.tif
# Processando: MOSAICO_2015_tile_10718.tif
# Processando: MOSAICO_2015_tile_10719.tif
# Processando: MOSAICO_2015_tile_10720.tif
# Processando: MOSAICO_2015_tile_10721.tif
# Processando: MOSAICO_2015_tile_10722.tif
# Processando: MOSAICO_2015_tile_10723.tif
# Processando: MOSAICO_2015_tile_10724.tif
# Processando: MOSAICO_2015_tile_10725.tif
# Processando: MOSAICO_2015_tile_10726.tif
# Processando: MOSAICO_2015_tile_10727.tif
# Processando: MOSAICO_2015_tile_10728.tif
# Processando: MOSAICO_2015_tile_10729.tif
# Processando: MOSAICO_2015_tile_10730.tif
# Processando: MOSAICO_2015_tile_10731.tif
# Processando: MOSAICO_2015_tile_10732.tif
# Processando: MOSAICO_2015_tile_10733.tif
# Processando: MOSAICO_2015_tile_10734.tif
# Processando: MOSAICO_2015_tile_10735.tif
# Processando: MOSAICO_2015_tile_10736.tif
# Processando: MOSAICO_2015_tile_10737.tif
# Processando: MOSAICO_2015_tile_10738.tif
# Processando: MOSAICO_2015_tile_10739.tif
# Processando: MOSAICO_2015_tile_10740.tif
# Processando: MOSAICO_2015_tile_10741.tif
# Processando: MOSAICO_2015_tile_10742.tif
# Processando: MOSAICO_2015_tile_10743.tif
# Processando: MOSAICO_2015_tile_10744.tif
# Processando: MOSAICO_2015_tile_10745.tif
# Processando: MOSAICO_2015_tile_10746.tif
# Processando: MOSAICO_2015_tile_10747.tif
# Processando: MOSAICO_2015_tile_10748.tif
# Processando: MOSAICO_2015_tile_10749.tif
# Processando: MOSAICO_2015_tile_10750.tif
# Processando: MOSAICO_2015_tile_10751.tif
# Processando: MOSAICO_2015_tile_10752.tif
# Processando: MOSAICO_2015_tile_10753.tif
# Processando: MOSAICO_2015_tile_10754.tif
# Processando: MOSAICO_2015_tile_10755.tif
# Processando: MOSAICO_2015_tile_10756.tif
# Processando: MOSAICO_2015_tile_10757.tif
# Processando: MOSAICO_2015_tile_10758.tif
# Processando: MOSAICO_2015_tile_10759.tif
# Processando: MOSAICO_2015_tile_10760.tif
# Processando: MOSAICO_2015_tile_10761.tif
# Processando: MOSAICO_2015_tile_10762.tif
# Processando: MOSAICO_2015_tile_10763.tif
# Processando: MOSAICO_2015_tile_10764.tif
# Processando: MOSAICO_2015_tile_10765.tif
# Processando: MOSAICO_2015_tile_10766.tif
# Processando: MOSAICO_2015_tile_10767.tif
# Processando: MOSAICO_2015_tile_10768.tif
# Processando: MOSAICO_2015_tile_10769.tif
# Processando: MOSAICO_2015_tile_10770.tif
# Processando: MOSAICO_2015_tile_10771.tif
# Processando: MOSAICO_2015_tile_10772.tif
# Processando: MOSAICO_2015_tile_10773.tif
# Processando: MOSAICO_2015_tile_10774.tif
# Processando: MOSAICO_2015_tile_10775.tif
# Processando: MOSAICO_2015_tile_10776.tif
# Processando: MOSAICO_2015_tile_10777.tif
# Processando: MOSAICO_2015_tile_10778.tif
# Processando: MOSAICO_2015_tile_10779.tif
# Processando: MOSAICO_2015_tile_10780.tif
# Processando: MOSAICO_2015_tile_10781.tif
# Processando: MOSAICO_2015_tile_10782.tif
# Processando: MOSAICO_2015_tile_10783.tif
# Processando: MOSAICO_2015_tile_10784.tif
# Processando: MOSAICO_2015_tile_10785.tif
# Processando: MOSAICO_2015_tile_10786.tif
# Processando: MOSAICO_2015_tile_10787.tif
# Processando: MOSAICO_2015_tile_10788.tif
# Processando: MOSAICO_2015_tile_10789.tif
# Processando: MOSAICO_2015_tile_10790.tif
# Processando: MOSAICO_2015_tile_10791.tif
# Processando: MOSAICO_2015_tile_10792.tif
# Processando: MOSAICO_2015_tile_10793.tif
# Processando: MOSAICO_2015_tile_10794.tif
# Processando: MOSAICO_2015_tile_10795.tif
# Processando: MOSAICO_2015_tile_10796.tif
# Processando: MOSAICO_2015_tile_10797.tif
# Processando: MOSAICO_2015_tile_10798.tif
# Processando: MOSAICO_2015_tile_10799.tif
# Processando: MOSAICO_2015_tile_108.tif
# Processando: MOSAICO_2015_tile_10800.tif
# Processando: MOSAICO_2015_tile_10801.tif
# Processando: MOSAICO_2015_tile_10802.tif
# Processando: MOSAICO_2015_tile_10803.tif
# Processando: MOSAICO_2015_tile_10804.tif
# Processando: MOSAICO_2015_tile_10805.tif
# Processando: MOSAICO_2015_tile_10806.tif
# Processando: MOSAICO_2015_tile_10807.tif
# Processando: MOSAICO_2015_tile_10808.tif
# Processando: MOSAICO_2015_tile_10809.tif
# Processando: MOSAICO_2015_tile_10810.tif
# Processando: MOSAICO_2015_tile_10811.tif
# Processando: MOSAICO_2015_tile_10812.tif
# Processando: MOSAICO_2015_tile_10813.tif
# Processando: MOSAICO_2015_tile_10814.tif
# Processando: MOSAICO_2015_tile_10815.tif
# Processando: MOSAICO_2015_tile_10816.tif
# Processando: MOSAICO_2015_tile_10817.tif
# Processando: MOSAICO_2015_tile_10818.tif
# Processando: MOSAICO_2015_tile_10819.tif
# Processando: MOSAICO_2015_tile_10820.tif
# Processando: MOSAICO_2015_tile_10821.tif
# Processando: MOSAICO_2015_tile_10822.tif
# Processando: MOSAICO_2015_tile_10823.tif
# Processando: MOSAICO_2015_tile_10824.tif
# Processando: MOSAICO_2015_tile_10825.tif
# Processando: MOSAICO_2015_tile_10826.tif
# Processando: MOSAICO_2015_tile_10827.tif
# Processando: MOSAICO_2015_tile_10828.tif
# Processando: MOSAICO_2015_tile_10829.tif
# Processando: MOSAICO_2015_tile_10830.tif
# Processando: MOSAICO_2015_tile_10831.tif
# Processando: MOSAICO_2015_tile_10832.tif
# Processando: MOSAICO_2015_tile_10833.tif
# Processando: MOSAICO_2015_tile_10834.tif
# Processando: MOSAICO_2015_tile_10835.tif
# Processando: MOSAICO_2015_tile_10836.tif
# Processando: MOSAICO_2015_tile_10837.tif
# Processando: MOSAICO_2015_tile_10838.tif
# Processando: MOSAICO_2015_tile_10839.tif
# Processando: MOSAICO_2015_tile_10840.tif
# Processando: MOSAICO_2015_tile_10841.tif
# Processando: MOSAICO_2015_tile_10842.tif
# Processando: MOSAICO_2015_tile_10843.tif
# Processando: MOSAICO_2015_tile_10844.tif
# Processando: MOSAICO_2015_tile_10845.tif
# Processando: MOSAICO_2015_tile_10846.tif
# Processando: MOSAICO_2015_tile_10847.tif
# Processando: MOSAICO_2015_tile_10848.tif
# Processando: MOSAICO_2015_tile_10849.tif
# Processando: MOSAICO_2015_tile_10850.tif
# Processando: MOSAICO_2015_tile_10851.tif
# Processando: MOSAICO_2015_tile_10852.tif
# Processando: MOSAICO_2015_tile_10853.tif
# Processando: MOSAICO_2015_tile_10854.tif
# Processando: MOSAICO_2015_tile_10855.tif
# Processando: MOSAICO_2015_tile_10856.tif
# Processando: MOSAICO_2015_tile_10857.tif
# Processando: MOSAICO_2015_tile_10858.tif
# Processando: MOSAICO_2015_tile_10859.tif
# Processando: MOSAICO_2015_tile_10860.tif
# Processando: MOSAICO_2015_tile_10861.tif
# Processando: MOSAICO_2015_tile_10862.tif
# Processando: MOSAICO_2015_tile_10863.tif
# Processando: MOSAICO_2015_tile_10864.tif
# Processando: MOSAICO_2015_tile_10865.tif
# Processando: MOSAICO_2015_tile_10866.tif
# Processando: MOSAICO_2015_tile_109.tif
# Processando: MOSAICO_2015_tile_10932.tif
# Processando: MOSAICO_2015_tile_10933.tif
# Processando: MOSAICO_2015_tile_10934.tif
# Processando: MOSAICO_2015_tile_10935.tif
# Processando: MOSAICO_2015_tile_10936.tif
# Processando: MOSAICO_2015_tile_10937.tif
# Processando: MOSAICO_2015_tile_10938.tif
# Processando: MOSAICO_2015_tile_10939.tif
# Processando: MOSAICO_2015_tile_10940.tif
# Processando: MOSAICO_2015_tile_10941.tif
# Processando: MOSAICO_2015_tile_10942.tif
# Processando: MOSAICO_2015_tile_10943.tif
# Processando: MOSAICO_2015_tile_10944.tif
# Processando: MOSAICO_2015_tile_10945.tif
# Processando: MOSAICO_2015_tile_10946.tif
# Processando: MOSAICO_2015_tile_10947.tif
# Processando: MOSAICO_2015_tile_10948.tif
# Processando: MOSAICO_2015_tile_10949.tif
# Processando: MOSAICO_2015_tile_10950.tif
# Processando: MOSAICO_2015_tile_10951.tif
# Processando: MOSAICO_2015_tile_10952.tif
# Processando: MOSAICO_2015_tile_10953.tif
# Processando: MOSAICO_2015_tile_10954.tif
# Processando: MOSAICO_2015_tile_10955.tif
# Processando: MOSAICO_2015_tile_10956.tif
# Processando: MOSAICO_2015_tile_10957.tif
# Processando: MOSAICO_2015_tile_10958.tif
# Processando: MOSAICO_2015_tile_10959.tif
# Processando: MOSAICO_2015_tile_10960.tif
# Processando: MOSAICO_2015_tile_10961.tif
# Processando: MOSAICO_2015_tile_10962.tif
# Processando: MOSAICO_2015_tile_10963.tif
# Processando: MOSAICO_2015_tile_10964.tif
# Processando: MOSAICO_2015_tile_10965.tif
# Processando: MOSAICO_2015_tile_10966.tif
# Processando: MOSAICO_2015_tile_10967.tif
# Processando: MOSAICO_2015_tile_10968.tif
# Processando: MOSAICO_2015_tile_10969.tif
# Processando: MOSAICO_2015_tile_10970.tif
# Processando: MOSAICO_2015_tile_10971.tif
# Processando: MOSAICO_2015_tile_10972.tif
# Processando: MOSAICO_2015_tile_10973.tif
# Processando: MOSAICO_2015_tile_10974.tif
# Processando: MOSAICO_2015_tile_10975.tif
# Processando: MOSAICO_2015_tile_10976.tif
# Processando: MOSAICO_2015_tile_10977.tif
# Processando: MOSAICO_2015_tile_10978.tif
# Processando: MOSAICO_2015_tile_10979.tif
# Processando: MOSAICO_2015_tile_10980.tif
# Processando: MOSAICO_2015_tile_10981.tif
# Processando: MOSAICO_2015_tile_10982.tif
# Processando: MOSAICO_2015_tile_10983.tif
# Processando: MOSAICO_2015_tile_10984.tif
# Processando: MOSAICO_2015_tile_10985.tif
# Processando: MOSAICO_2015_tile_10986.tif
# Processando: MOSAICO_2015_tile_10987.tif
# Processando: MOSAICO_2015_tile_10988.tif
# Processando: MOSAICO_2015_tile_10989.tif
# Processando: MOSAICO_2015_tile_10990.tif
# Processando: MOSAICO_2015_tile_10991.tif
# Processando: MOSAICO_2015_tile_10992.tif
# Processando: MOSAICO_2015_tile_10993.tif
# Processando: MOSAICO_2015_tile_10994.tif
# Processando: MOSAICO_2015_tile_10995.tif
# Processando: MOSAICO_2015_tile_10996.tif
# Processando: MOSAICO_2015_tile_10997.tif
# Processando: MOSAICO_2015_tile_10998.tif
# Processando: MOSAICO_2015_tile_10999.tif
# Processando: MOSAICO_2015_tile_110.tif
# Processando: MOSAICO_2015_tile_11000.tif
# Processando: MOSAICO_2015_tile_11001.tif
# Processando: MOSAICO_2015_tile_11002.tif
# Processando: MOSAICO_2015_tile_11003.tif
# Processando: MOSAICO_2015_tile_11004.tif
# Processando: MOSAICO_2015_tile_11005.tif
# Processando: MOSAICO_2015_tile_11006.tif
# Processando: MOSAICO_2015_tile_11007.tif
# Processando: MOSAICO_2015_tile_11008.tif
# Processando: MOSAICO_2015_tile_11009.tif
# Processando: MOSAICO_2015_tile_11010.tif
# Processando: MOSAICO_2015_tile_11011.tif
# Processando: MOSAICO_2015_tile_11012.tif
# Processando: MOSAICO_2015_tile_11013.tif
# Processando: MOSAICO_2015_tile_11014.tif
# Processando: MOSAICO_2015_tile_11015.tif
# Processando: MOSAICO_2015_tile_11016.tif
# Processando: MOSAICO_2015_tile_11017.tif
# Processando: MOSAICO_2015_tile_11018.tif
# Processando: MOSAICO_2015_tile_11019.tif
# Processando: MOSAICO_2015_tile_11020.tif
# Processando: MOSAICO_2015_tile_11021.tif
# Processando: MOSAICO_2015_tile_11022.tif
# Processando: MOSAICO_2015_tile_11023.tif
# Processando: MOSAICO_2015_tile_11024.tif
# Processando: MOSAICO_2015_tile_11025.tif
# Processando: MOSAICO_2015_tile_11026.tif
# Processando: MOSAICO_2015_tile_11027.tif
# Processando: MOSAICO_2015_tile_11028.tif
# Processando: MOSAICO_2015_tile_11029.tif
# Processando: MOSAICO_2015_tile_11030.tif
# Processando: MOSAICO_2015_tile_11031.tif
# Processando: MOSAICO_2015_tile_11032.tif
# Processando: MOSAICO_2015_tile_11033.tif
# Processando: MOSAICO_2015_tile_11034.tif
# Processando: MOSAICO_2015_tile_11035.tif
# Processando: MOSAICO_2015_tile_11036.tif
# Processando: MOSAICO_2015_tile_11037.tif
# Processando: MOSAICO_2015_tile_11038.tif
# Processando: MOSAICO_2015_tile_11039.tif
# Processando: MOSAICO_2015_tile_11040.tif
# Processando: MOSAICO_2015_tile_11041.tif
# Processando: MOSAICO_2015_tile_11042.tif
# Processando: MOSAICO_2015_tile_11043.tif
# Processando: MOSAICO_2015_tile_11044.tif
# Processando: MOSAICO_2015_tile_11045.tif
# Processando: MOSAICO_2015_tile_11046.tif
# Processando: MOSAICO_2015_tile_11047.tif
# Processando: MOSAICO_2015_tile_11048.tif
# Processando: MOSAICO_2015_tile_11049.tif
# Processando: MOSAICO_2015_tile_11050.tif
# Processando: MOSAICO_2015_tile_11051.tif
# Processando: MOSAICO_2015_tile_11052.tif
# Processando: MOSAICO_2015_tile_11053.tif
# Processando: MOSAICO_2015_tile_11054.tif
# Processando: MOSAICO_2015_tile_11055.tif
# Processando: MOSAICO_2015_tile_11056.tif
# Processando: MOSAICO_2015_tile_11057.tif
# Processando: MOSAICO_2015_tile_11058.tif
# Processando: MOSAICO_2015_tile_11059.tif
# Processando: MOSAICO_2015_tile_11060.tif
# Processando: MOSAICO_2015_tile_11061.tif
# Processando: MOSAICO_2015_tile_11062.tif
# Processando: MOSAICO_2015_tile_11063.tif
# Processando: MOSAICO_2015_tile_11064.tif
# Processando: MOSAICO_2015_tile_11065.tif
# Processando: MOSAICO_2015_tile_11066.tif
# Processando: MOSAICO_2015_tile_11067.tif
# Processando: MOSAICO_2015_tile_11068.tif
# Processando: MOSAICO_2015_tile_11069.tif
# Processando: MOSAICO_2015_tile_11070.tif
# Processando: MOSAICO_2015_tile_11071.tif
# Processando: MOSAICO_2015_tile_11072.tif
# Processando: MOSAICO_2015_tile_11073.tif
# Processando: MOSAICO_2015_tile_11074.tif
# Processando: MOSAICO_2015_tile_11075.tif
# Processando: MOSAICO_2015_tile_11076.tif
# Processando: MOSAICO_2015_tile_11077.tif
# Processando: MOSAICO_2015_tile_11078.tif
# Processando: MOSAICO_2015_tile_11079.tif
# Processando: MOSAICO_2015_tile_11080.tif
# Processando: MOSAICO_2015_tile_11081.tif
# Processando: MOSAICO_2015_tile_11082.tif
# Processando: MOSAICO_2015_tile_11083.tif
# Processando: MOSAICO_2015_tile_11084.tif
# Processando: MOSAICO_2015_tile_11085.tif
# Processando: MOSAICO_2015_tile_11086.tif
# Processando: MOSAICO_2015_tile_11087.tif
# Processando: MOSAICO_2015_tile_11088.tif
# Processando: MOSAICO_2015_tile_11089.tif
# Processando: MOSAICO_2015_tile_111.tif
# Processando: MOSAICO_2015_tile_11154.tif
# Processando: MOSAICO_2015_tile_11155.tif
# Processando: MOSAICO_2015_tile_11156.tif
# Processando: MOSAICO_2015_tile_11157.tif
# Processando: MOSAICO_2015_tile_11158.tif
# Processando: MOSAICO_2015_tile_11159.tif
# Processando: MOSAICO_2015_tile_11160.tif
# Processando: MOSAICO_2015_tile_11161.tif
# Processando: MOSAICO_2015_tile_11162.tif
# Processando: MOSAICO_2015_tile_11163.tif
# Processando: MOSAICO_2015_tile_11164.tif
# Processando: MOSAICO_2015_tile_11165.tif
# Processando: MOSAICO_2015_tile_11166.tif
# Processando: MOSAICO_2015_tile_11167.tif
# Processando: MOSAICO_2015_tile_11168.tif
# Processando: MOSAICO_2015_tile_11169.tif
# Processando: MOSAICO_2015_tile_11170.tif
# Processando: MOSAICO_2015_tile_11171.tif
# Processando: MOSAICO_2015_tile_11172.tif
# Processando: MOSAICO_2015_tile_11173.tif
# Processando: MOSAICO_2015_tile_11174.tif
# Processando: MOSAICO_2015_tile_11175.tif
# Processando: MOSAICO_2015_tile_11176.tif
# Processando: MOSAICO_2015_tile_11177.tif
# Processando: MOSAICO_2015_tile_11178.tif
# Processando: MOSAICO_2015_tile_11179.tif
# Processando: MOSAICO_2015_tile_11180.tif
# Processando: MOSAICO_2015_tile_11181.tif
# Processando: MOSAICO_2015_tile_11182.tif
# Processando: MOSAICO_2015_tile_11183.tif
# Processando: MOSAICO_2015_tile_11184.tif
# Processando: MOSAICO_2015_tile_11185.tif
# Processando: MOSAICO_2015_tile_11186.tif
# Processando: MOSAICO_2015_tile_11187.tif
# Processando: MOSAICO_2015_tile_11188.tif
# Processando: MOSAICO_2015_tile_11189.tif
# Processando: MOSAICO_2015_tile_11190.tif
# Processando: MOSAICO_2015_tile_11191.tif
# Processando: MOSAICO_2015_tile_11192.tif
# Processando: MOSAICO_2015_tile_11193.tif
# Processando: MOSAICO_2015_tile_11194.tif
# Processando: MOSAICO_2015_tile_11195.tif
# Processando: MOSAICO_2015_tile_11196.tif
# Processando: MOSAICO_2015_tile_11197.tif
# Processando: MOSAICO_2015_tile_11198.tif
# Processando: MOSAICO_2015_tile_11199.tif
# Processando: MOSAICO_2015_tile_112.tif
# Processando: MOSAICO_2015_tile_11200.tif
# Processando: MOSAICO_2015_tile_11201.tif
# Processando: MOSAICO_2015_tile_11202.tif
# Processando: MOSAICO_2015_tile_11203.tif
# Processando: MOSAICO_2015_tile_11204.tif
# Processando: MOSAICO_2015_tile_11205.tif
# Processando: MOSAICO_2015_tile_11206.tif
# Processando: MOSAICO_2015_tile_11207.tif
# Processando: MOSAICO_2015_tile_11208.tif
# Processando: MOSAICO_2015_tile_11209.tif
# Processando: MOSAICO_2015_tile_11210.tif
# Processando: MOSAICO_2015_tile_11211.tif
# Processando: MOSAICO_2015_tile_11212.tif
# Processando: MOSAICO_2015_tile_11213.tif
# Processando: MOSAICO_2015_tile_11214.tif
# Processando: MOSAICO_2015_tile_11215.tif
# Processando: MOSAICO_2015_tile_11216.tif
# Processando: MOSAICO_2015_tile_11217.tif
# Processando: MOSAICO_2015_tile_11218.tif
# Processando: MOSAICO_2015_tile_11219.tif
# Processando: MOSAICO_2015_tile_11220.tif
# Processando: MOSAICO_2015_tile_11221.tif
# Processando: MOSAICO_2015_tile_11222.tif
# Processando: MOSAICO_2015_tile_11223.tif
# Processando: MOSAICO_2015_tile_11224.tif
# Processando: MOSAICO_2015_tile_11225.tif
# Processando: MOSAICO_2015_tile_11226.tif
# Processando: MOSAICO_2015_tile_11227.tif
# Processando: MOSAICO_2015_tile_11228.tif
# Processando: MOSAICO_2015_tile_11229.tif
# Processando: MOSAICO_2015_tile_11230.tif
# Processando: MOSAICO_2015_tile_11231.tif
# Processando: MOSAICO_2015_tile_11232.tif
# Processando: MOSAICO_2015_tile_11233.tif
# Processando: MOSAICO_2015_tile_11234.tif
# Processando: MOSAICO_2015_tile_11235.tif
# Processando: MOSAICO_2015_tile_11236.tif
# Processando: MOSAICO_2015_tile_11237.tif
# Processando: MOSAICO_2015_tile_11238.tif
# Processando: MOSAICO_2015_tile_11239.tif
# Processando: MOSAICO_2015_tile_11240.tif
# Processando: MOSAICO_2015_tile_11241.tif
# Processando: MOSAICO_2015_tile_11242.tif
# Processando: MOSAICO_2015_tile_11243.tif
# Processando: MOSAICO_2015_tile_11244.tif
# Processando: MOSAICO_2015_tile_11245.tif
# Processando: MOSAICO_2015_tile_11246.tif
# Processando: MOSAICO_2015_tile_11247.tif
# Processando: MOSAICO_2015_tile_11248.tif
# Processando: MOSAICO_2015_tile_11249.tif
# Processando: MOSAICO_2015_tile_11250.tif
# Processando: MOSAICO_2015_tile_11251.tif
# Processando: MOSAICO_2015_tile_11252.tif
# Processando: MOSAICO_2015_tile_11253.tif
# Processando: MOSAICO_2015_tile_11254.tif
# Processando: MOSAICO_2015_tile_11255.tif
# Processando: MOSAICO_2015_tile_11256.tif
# Processando: MOSAICO_2015_tile_11257.tif
# Processando: MOSAICO_2015_tile_11258.tif
# Processando: MOSAICO_2015_tile_11259.tif
# Processando: MOSAICO_2015_tile_11260.tif
# Processando: MOSAICO_2015_tile_11261.tif
# Processando: MOSAICO_2015_tile_11262.tif
# Processando: MOSAICO_2015_tile_11263.tif
# Processando: MOSAICO_2015_tile_11264.tif
# Processando: MOSAICO_2015_tile_11265.tif
# Processando: MOSAICO_2015_tile_11266.tif
# Processando: MOSAICO_2015_tile_11267.tif
# Processando: MOSAICO_2015_tile_11268.tif
# Processando: MOSAICO_2015_tile_11269.tif
# Processando: MOSAICO_2015_tile_11270.tif
# Processando: MOSAICO_2015_tile_11271.tif
# Processando: MOSAICO_2015_tile_11272.tif
# Processando: MOSAICO_2015_tile_11273.tif
# Processando: MOSAICO_2015_tile_11274.tif
# Processando: MOSAICO_2015_tile_11275.tif
# Processando: MOSAICO_2015_tile_11276.tif
# Processando: MOSAICO_2015_tile_11277.tif
# Processando: MOSAICO_2015_tile_11278.tif
# Processando: MOSAICO_2015_tile_11279.tif
# Processando: MOSAICO_2015_tile_11280.tif
# Processando: MOSAICO_2015_tile_11281.tif
# Processando: MOSAICO_2015_tile_11282.tif
# Processando: MOSAICO_2015_tile_11283.tif
# Processando: MOSAICO_2015_tile_11284.tif
# Processando: MOSAICO_2015_tile_11285.tif
# Processando: MOSAICO_2015_tile_11286.tif
# Processando: MOSAICO_2015_tile_11287.tif
# Processando: MOSAICO_2015_tile_11288.tif
# Processando: MOSAICO_2015_tile_11289.tif
# Processando: MOSAICO_2015_tile_11290.tif
# Processando: MOSAICO_2015_tile_11291.tif
# Processando: MOSAICO_2015_tile_11292.tif
# Processando: MOSAICO_2015_tile_11293.tif
# Processando: MOSAICO_2015_tile_11294.tif
# Processando: MOSAICO_2015_tile_11295.tif
# Processando: MOSAICO_2015_tile_11296.tif
# Processando: MOSAICO_2015_tile_11297.tif
# Processando: MOSAICO_2015_tile_11298.tif
# Processando: MOSAICO_2015_tile_11299.tif
# Processando: MOSAICO_2015_tile_113.tif
# Processando: MOSAICO_2015_tile_11300.tif
# Processando: MOSAICO_2015_tile_11301.tif
# Processando: MOSAICO_2015_tile_11302.tif
# Processando: MOSAICO_2015_tile_11303.tif
# Processando: MOSAICO_2015_tile_11304.tif
# Processando: MOSAICO_2015_tile_11305.tif
# Processando: MOSAICO_2015_tile_11306.tif
# Processando: MOSAICO_2015_tile_11307.tif
# Processando: MOSAICO_2015_tile_11308.tif
# Processando: MOSAICO_2015_tile_11309.tif
# Processando: MOSAICO_2015_tile_11310.tif
# Processando: MOSAICO_2015_tile_11311.tif
# Processando: MOSAICO_2015_tile_11375.tif
# Processando: MOSAICO_2015_tile_11376.tif
# Processando: MOSAICO_2015_tile_11377.tif
# Processando: MOSAICO_2015_tile_11378.tif
# Processando: MOSAICO_2015_tile_11379.tif
# Processando: MOSAICO_2015_tile_11380.tif
# Processando: MOSAICO_2015_tile_11381.tif
# Processando: MOSAICO_2015_tile_11382.tif
# Processando: MOSAICO_2015_tile_11383.tif
# Processando: MOSAICO_2015_tile_11384.tif
# Processando: MOSAICO_2015_tile_11385.tif
# Processando: MOSAICO_2015_tile_11386.tif
# Processando: MOSAICO_2015_tile_11387.tif
# Processando: MOSAICO_2015_tile_11388.tif
# Processando: MOSAICO_2015_tile_11389.tif
# Processando: MOSAICO_2015_tile_11390.tif
# Processando: MOSAICO_2015_tile_11391.tif
# Processando: MOSAICO_2015_tile_11392.tif
# Processando: MOSAICO_2015_tile_11393.tif
# Processando: MOSAICO_2015_tile_11394.tif
# Processando: MOSAICO_2015_tile_11395.tif
# Processando: MOSAICO_2015_tile_11396.tif
# Processando: MOSAICO_2015_tile_11397.tif
# Processando: MOSAICO_2015_tile_11398.tif
# Processando: MOSAICO_2015_tile_11399.tif
# Processando: MOSAICO_2015_tile_114.tif
# Processando: MOSAICO_2015_tile_11400.tif
# Processando: MOSAICO_2015_tile_11401.tif
# Processando: MOSAICO_2015_tile_11402.tif
# Processando: MOSAICO_2015_tile_11403.tif
# Processando: MOSAICO_2015_tile_11404.tif
# Processando: MOSAICO_2015_tile_11405.tif
# Processando: MOSAICO_2015_tile_11406.tif
# Processando: MOSAICO_2015_tile_11407.tif
# Processando: MOSAICO_2015_tile_11408.tif
# Processando: MOSAICO_2015_tile_11409.tif
# Processando: MOSAICO_2015_tile_11410.tif
# Processando: MOSAICO_2015_tile_11411.tif
# Processando: MOSAICO_2015_tile_11412.tif
# Processando: MOSAICO_2015_tile_11413.tif
# Processando: MOSAICO_2015_tile_11414.tif
# Processando: MOSAICO_2015_tile_11415.tif
# Processando: MOSAICO_2015_tile_11416.tif
# Processando: MOSAICO_2015_tile_11417.tif
# Processando: MOSAICO_2015_tile_11418.tif
# Processando: MOSAICO_2015_tile_11419.tif
# Processando: MOSAICO_2015_tile_11420.tif
# Processando: MOSAICO_2015_tile_11421.tif
# Processando: MOSAICO_2015_tile_11422.tif
# Processando: MOSAICO_2015_tile_11423.tif
# Processando: MOSAICO_2015_tile_11424.tif
# Processando: MOSAICO_2015_tile_11425.tif
# Processando: MOSAICO_2015_tile_11426.tif
# Processando: MOSAICO_2015_tile_11427.tif
# Processando: MOSAICO_2015_tile_11428.tif
# Processando: MOSAICO_2015_tile_11429.tif
# Processando: MOSAICO_2015_tile_11430.tif
# Processando: MOSAICO_2015_tile_11431.tif
# Processando: MOSAICO_2015_tile_11432.tif
# Processando: MOSAICO_2015_tile_11433.tif
# Processando: MOSAICO_2015_tile_11434.tif
# Processando: MOSAICO_2015_tile_11435.tif
# Processando: MOSAICO_2015_tile_11436.tif
# Processando: MOSAICO_2015_tile_11437.tif
# Processando: MOSAICO_2015_tile_11438.tif
# Processando: MOSAICO_2015_tile_11439.tif
# Processando: MOSAICO_2015_tile_11440.tif
# Processando: MOSAICO_2015_tile_11441.tif
# Processando: MOSAICO_2015_tile_11442.tif
# Processando: MOSAICO_2015_tile_11443.tif
# Processando: MOSAICO_2015_tile_11444.tif
# Processando: MOSAICO_2015_tile_11445.tif
# Processando: MOSAICO_2015_tile_11446.tif
# Processando: MOSAICO_2015_tile_11447.tif
# Processando: MOSAICO_2015_tile_11448.tif
# Processando: MOSAICO_2015_tile_11449.tif
# Processando: MOSAICO_2015_tile_11450.tif
# Processando: MOSAICO_2015_tile_11451.tif
# Processando: MOSAICO_2015_tile_11452.tif
# Processando: MOSAICO_2015_tile_11453.tif
# Processando: MOSAICO_2015_tile_11454.tif
# Processando: MOSAICO_2015_tile_11455.tif
# Processando: MOSAICO_2015_tile_11456.tif
# Processando: MOSAICO_2015_tile_11457.tif
# Processando: MOSAICO_2015_tile_11458.tif
# Processando: MOSAICO_2015_tile_11459.tif
# Processando: MOSAICO_2015_tile_11460.tif
# Processando: MOSAICO_2015_tile_11461.tif
# Processando: MOSAICO_2015_tile_11462.tif
# Processando: MOSAICO_2015_tile_11463.tif
# Processando: MOSAICO_2015_tile_11464.tif
# Processando: MOSAICO_2015_tile_11465.tif
# Processando: MOSAICO_2015_tile_11466.tif
# Processando: MOSAICO_2015_tile_11467.tif
# Processando: MOSAICO_2015_tile_11468.tif
# Processando: MOSAICO_2015_tile_11469.tif
# Processando: MOSAICO_2015_tile_11470.tif
# Processando: MOSAICO_2015_tile_11471.tif
# Processando: MOSAICO_2015_tile_11472.tif
# Processando: MOSAICO_2015_tile_11473.tif
# Processando: MOSAICO_2015_tile_11474.tif
# Processando: MOSAICO_2015_tile_11475.tif
# Processando: MOSAICO_2015_tile_11476.tif
# Processando: MOSAICO_2015_tile_11477.tif
# Processando: MOSAICO_2015_tile_11478.tif
# Processando: MOSAICO_2015_tile_11479.tif
# Processando: MOSAICO_2015_tile_11480.tif
# Processando: MOSAICO_2015_tile_11481.tif
# Processando: MOSAICO_2015_tile_11482.tif
# Processando: MOSAICO_2015_tile_11483.tif
# Processando: MOSAICO_2015_tile_11484.tif
# Processando: MOSAICO_2015_tile_11485.tif
# Processando: MOSAICO_2015_tile_11486.tif
# Processando: MOSAICO_2015_tile_11487.tif
# Processando: MOSAICO_2015_tile_11488.tif
# Processando: MOSAICO_2015_tile_11489.tif
# Processando: MOSAICO_2015_tile_11490.tif
# Processando: MOSAICO_2015_tile_11491.tif
# Processando: MOSAICO_2015_tile_11492.tif
# Processando: MOSAICO_2015_tile_11493.tif
# Processando: MOSAICO_2015_tile_11494.tif
# Processando: MOSAICO_2015_tile_11495.tif
# Processando: MOSAICO_2015_tile_11496.tif
# Processando: MOSAICO_2015_tile_11497.tif
# Processando: MOSAICO_2015_tile_11498.tif
# Processando: MOSAICO_2015_tile_11499.tif
# Processando: MOSAICO_2015_tile_115.tif
# Processando: MOSAICO_2015_tile_11500.tif
# Processando: MOSAICO_2015_tile_11501.tif
# Processando: MOSAICO_2015_tile_11502.tif
# Processando: MOSAICO_2015_tile_11503.tif
# Processando: MOSAICO_2015_tile_11504.tif
# Processando: MOSAICO_2015_tile_11505.tif
# Processando: MOSAICO_2015_tile_11506.tif
# Processando: MOSAICO_2015_tile_11507.tif
# Processando: MOSAICO_2015_tile_11508.tif
# Processando: MOSAICO_2015_tile_11509.tif
# Processando: MOSAICO_2015_tile_11510.tif
# Processando: MOSAICO_2015_tile_11511.tif
# Processando: MOSAICO_2015_tile_11512.tif
# Processando: MOSAICO_2015_tile_11513.tif
# Processando: MOSAICO_2015_tile_11514.tif
# Processando: MOSAICO_2015_tile_11515.tif
# Processando: MOSAICO_2015_tile_11516.tif
# Processando: MOSAICO_2015_tile_11517.tif
# Processando: MOSAICO_2015_tile_11518.tif
# Processando: MOSAICO_2015_tile_11519.tif
# Processando: MOSAICO_2015_tile_11520.tif
# Processando: MOSAICO_2015_tile_11521.tif
# Processando: MOSAICO_2015_tile_11522.tif
# Processando: MOSAICO_2015_tile_11523.tif
# Processando: MOSAICO_2015_tile_11524.tif
# Processando: MOSAICO_2015_tile_11525.tif
# Processando: MOSAICO_2015_tile_11526.tif
# Processando: MOSAICO_2015_tile_11527.tif
# Processando: MOSAICO_2015_tile_11528.tif
# Processando: MOSAICO_2015_tile_11529.tif
# Processando: MOSAICO_2015_tile_11530.tif
# Processando: MOSAICO_2015_tile_11531.tif
# Processando: MOSAICO_2015_tile_11532.tif
# Processando: MOSAICO_2015_tile_11533.tif
# Processando: MOSAICO_2015_tile_11597.tif
# Processando: MOSAICO_2015_tile_11598.tif
# Processando: MOSAICO_2015_tile_11599.tif
# Processando: MOSAICO_2015_tile_116.tif
# Processando: MOSAICO_2015_tile_11600.tif
# Processando: MOSAICO_2015_tile_11601.tif
# Processando: MOSAICO_2015_tile_11602.tif
# Processando: MOSAICO_2015_tile_11603.tif
# Processando: MOSAICO_2015_tile_11604.tif
# Processando: MOSAICO_2015_tile_11605.tif
# Processando: MOSAICO_2015_tile_11606.tif
# Processando: MOSAICO_2015_tile_11607.tif
# Processando: MOSAICO_2015_tile_11608.tif
# Processando: MOSAICO_2015_tile_11609.tif
# Processando: MOSAICO_2015_tile_11610.tif
# Processando: MOSAICO_2015_tile_11611.tif
# Processando: MOSAICO_2015_tile_11612.tif
# Processando: MOSAICO_2015_tile_11613.tif
# Processando: MOSAICO_2015_tile_11614.tif
# Processando: MOSAICO_2015_tile_11615.tif
# Processando: MOSAICO_2015_tile_11616.tif
# Processando: MOSAICO_2015_tile_11617.tif
# Processando: MOSAICO_2015_tile_11618.tif
# Processando: MOSAICO_2015_tile_11619.tif
# Processando: MOSAICO_2015_tile_11620.tif
# Processando: MOSAICO_2015_tile_11621.tif
# Processando: MOSAICO_2015_tile_11622.tif
# Processando: MOSAICO_2015_tile_11623.tif
# Processando: MOSAICO_2015_tile_11624.tif
# Processando: MOSAICO_2015_tile_11625.tif
# Processando: MOSAICO_2015_tile_11626.tif
# Processando: MOSAICO_2015_tile_11627.tif
# Processando: MOSAICO_2015_tile_11628.tif
# Processando: MOSAICO_2015_tile_11629.tif
# Processando: MOSAICO_2015_tile_11630.tif
# Processando: MOSAICO_2015_tile_11631.tif
# Processando: MOSAICO_2015_tile_11632.tif
# Processando: MOSAICO_2015_tile_11633.tif
# Processando: MOSAICO_2015_tile_11634.tif
# Processando: MOSAICO_2015_tile_11635.tif
# Processando: MOSAICO_2015_tile_11636.tif
# Processando: MOSAICO_2015_tile_11637.tif
# Processando: MOSAICO_2015_tile_11638.tif
# Processando: MOSAICO_2015_tile_11639.tif
# Processando: MOSAICO_2015_tile_11640.tif
# Processando: MOSAICO_2015_tile_11641.tif
# Processando: MOSAICO_2015_tile_11642.tif
# Processando: MOSAICO_2015_tile_11643.tif
# Processando: MOSAICO_2015_tile_11644.tif
# Processando: MOSAICO_2015_tile_11645.tif
# Processando: MOSAICO_2015_tile_11646.tif
# Processando: MOSAICO_2015_tile_11647.tif
# Processando: MOSAICO_2015_tile_11648.tif
# Processando: MOSAICO_2015_tile_11649.tif
# Processando: MOSAICO_2015_tile_11650.tif
# Processando: MOSAICO_2015_tile_11651.tif
# Processando: MOSAICO_2015_tile_11652.tif
# Processando: MOSAICO_2015_tile_11653.tif
# Processando: MOSAICO_2015_tile_11654.tif
# Processando: MOSAICO_2015_tile_11655.tif
# Processando: MOSAICO_2015_tile_11656.tif
# Processando: MOSAICO_2015_tile_11657.tif
# Processando: MOSAICO_2015_tile_11658.tif
# Processando: MOSAICO_2015_tile_11659.tif
# Processando: MOSAICO_2015_tile_11660.tif
# Processando: MOSAICO_2015_tile_11661.tif
# Processando: MOSAICO_2015_tile_11662.tif
# Processando: MOSAICO_2015_tile_11663.tif
# Processando: MOSAICO_2015_tile_11664.tif
# Processando: MOSAICO_2015_tile_11665.tif
# Processando: MOSAICO_2015_tile_11666.tif
# Processando: MOSAICO_2015_tile_11667.tif
# Processando: MOSAICO_2015_tile_11668.tif
# Processando: MOSAICO_2015_tile_11669.tif
# Processando: MOSAICO_2015_tile_11670.tif
# Processando: MOSAICO_2015_tile_11671.tif
# Processando: MOSAICO_2015_tile_11672.tif
# Processando: MOSAICO_2015_tile_11673.tif
# Processando: MOSAICO_2015_tile_11674.tif
# Processando: MOSAICO_2015_tile_11675.tif
# Processando: MOSAICO_2015_tile_11676.tif
# Processando: MOSAICO_2015_tile_11677.tif
# Processando: MOSAICO_2015_tile_11678.tif
# Processando: MOSAICO_2015_tile_11679.tif
# Processando: MOSAICO_2015_tile_11680.tif
# ...
# Processando: MOSAICO_2015_tile_9417.tif
# Processando: MOSAICO_2015_tile_9418.tif
# Processando: MOSAICO_2015_tile_9419.tif
# Processando: MOSAICO_2015_tile_9420.tif
# Processando: MOSAICO_2015_tile_9421.tif
# Processando: MOSAICO_2015_tile_9422.tif
# Processando: MOSAICO_2015_tile_9423.tif
# Processando: MOSAICO_2015_tile_9424.tif
# Processando: MOSAICO_2015_tile_9425.tif
# Processando: MOSAICO_2015_tile_9426.tif
# Processando: MOSAICO_2015_tile_9427.tif
# Processando: MOSAICO_2015_tile_9428.tif
# Processando: MOSAICO_2015_tile_9429.tif
# Processando: MOSAICO_2015_tile_9430.tif
# Processando: MOSAICO_2015_tile_9431.tif
# Processando: MOSAICO_2015_tile_9432.tif
# Processando: MOSAICO_2015_tile_9433.tif
# Processando: MOSAICO_2015_tile_9434.tif
# Processando: MOSAICO_2015_tile_9435.tif
# Processando: MOSAICO_2015_tile_9436.tif
# Processando: MOSAICO_2015_tile_9437.tif
# Processando: MOSAICO_2015_tile_9438.tif
# Processando: MOSAICO_2015_tile_9439.tif
# Processando: MOSAICO_2015_tile_9440.tif
# Processando: MOSAICO_2015_tile_9441.tif
# Processando: MOSAICO_2015_tile_9442.tif
# Processando: MOSAICO_2015_tile_9443.tif
# Processando: MOSAICO_2015_tile_9444.tif
# Processando: MOSAICO_2015_tile_9445.tif
# Processando: MOSAICO_2015_tile_9446.tif
# Processando: MOSAICO_2015_tile_9447.tif
# Processando: MOSAICO_2015_tile_9448.tif
# Processando: MOSAICO_2015_tile_9449.tif
# Processando: MOSAICO_2015_tile_9450.tif
# Processando: MOSAICO_2015_tile_9451.tif
# Processando: MOSAICO_2015_tile_9452.tif
# Processando: MOSAICO_2015_tile_9453.tif
# Processando: MOSAICO_2015_tile_9454.tif
# Processando: MOSAICO_2015_tile_9455.tif
# Processando: MOSAICO_2015_tile_9456.tif
# Processando: MOSAICO_2015_tile_9457.tif
# Processando: MOSAICO_2015_tile_9458.tif
# Processando: MOSAICO_2015_tile_9459.tif
# Processando: MOSAICO_2015_tile_9460.tif
# Processando: MOSAICO_2015_tile_9461.tif
# Processando: MOSAICO_2015_tile_9462.tif
# Processando: MOSAICO_2015_tile_9463.tif
# Processando: MOSAICO_2015_tile_9464.tif
# Processando: MOSAICO_2015_tile_9465.tif
# Processando: MOSAICO_2015_tile_9466.tif
# Processando: MOSAICO_2015_tile_9467.tif
# Processando: MOSAICO_2015_tile_9468.tif
# Processando: MOSAICO_2015_tile_9469.tif
# Processando: MOSAICO_2015_tile_9470.tif
# Processando: MOSAICO_2015_tile_9471.tif
# Processando: MOSAICO_2015_tile_9472.tif
# Processando: MOSAICO_2015_tile_9473.tif
# Processando: MOSAICO_2015_tile_9474.tif
# Processando: MOSAICO_2015_tile_9475.tif
# Processando: MOSAICO_2015_tile_9476.tif
# Processando: MOSAICO_2015_tile_9477.tif
# Processando: MOSAICO_2015_tile_9478.tif
# Processando: MOSAICO_2015_tile_9479.tif
# Processando: MOSAICO_2015_tile_9480.tif
# Processando: MOSAICO_2015_tile_9481.tif
# Processando: MOSAICO_2015_tile_9482.tif
# Processando: MOSAICO_2015_tile_9483.tif
# Processando: MOSAICO_2015_tile_9484.tif
# Processando: MOSAICO_2015_tile_9485.tif
# Processando: MOSAICO_2015_tile_9486.tif
# Processando: MOSAICO_2015_tile_9487.tif
# Processando: MOSAICO_2015_tile_9488.tif
# Processando: MOSAICO_2015_tile_9489.tif
# Processando: MOSAICO_2015_tile_9490.tif
# Processando: MOSAICO_2015_tile_9491.tif
# Processando: MOSAICO_2015_tile_9492.tif
# Processando: MOSAICO_2015_tile_9493.tif
# Processando: MOSAICO_2015_tile_9494.tif
# Processando: MOSAICO_2015_tile_9495.tif
# Processando: MOSAICO_2015_tile_9496.tif
# Processando: MOSAICO_2015_tile_9497.tif
# Processando: MOSAICO_2015_tile_9498.tif
# Processando: MOSAICO_2015_tile_9499.tif
# Processando: MOSAICO_2015_tile_9500.tif
# Processando: MOSAICO_2015_tile_9501.tif
# Processando: MOSAICO_2015_tile_9502.tif
# Processando: MOSAICO_2015_tile_9503.tif
# Processando: MOSAICO_2015_tile_9504.tif
# Processando: MOSAICO_2015_tile_9505.tif
# Processando: MOSAICO_2015_tile_9506.tif
# Processando: MOSAICO_2015_tile_9507.tif
# Processando: MOSAICO_2015_tile_9508.tif
# Processando: MOSAICO_2015_tile_9509.tif
# Processando: MOSAICO_2015_tile_9510.tif
# Processando: MOSAICO_2015_tile_9511.tif
# Processando: MOSAICO_2015_tile_9512.tif
# Processando: MOSAICO_2015_tile_9513.tif
# Processando: MOSAICO_2015_tile_9514.tif
# Processando: MOSAICO_2015_tile_9515.tif
# Processando: MOSAICO_2015_tile_9516.tif
# Processando: MOSAICO_2015_tile_9517.tif
# Processando: MOSAICO_2015_tile_9518.tif
# Processando: MOSAICO_2015_tile_9519.tif
# Processando: MOSAICO_2015_tile_9520.tif
# Processando: MOSAICO_2015_tile_9521.tif
# Processando: MOSAICO_2015_tile_9522.tif
# Processando: MOSAICO_2015_tile_9523.tif
# Processando: MOSAICO_2015_tile_9524.tif
# Processando: MOSAICO_2015_tile_9605.tif
# Processando: MOSAICO_2015_tile_9606.tif
# Processando: MOSAICO_2015_tile_9607.tif
# Processando: MOSAICO_2015_tile_9608.tif
# Processando: MOSAICO_2015_tile_9609.tif
# Processando: MOSAICO_2015_tile_9610.tif
# Processando: MOSAICO_2015_tile_9611.tif
# Processando: MOSAICO_2015_tile_9612.tif
# Processando: MOSAICO_2015_tile_9613.tif
# Processando: MOSAICO_2015_tile_9614.tif
# Processando: MOSAICO_2015_tile_9615.tif
# Processando: MOSAICO_2015_tile_9616.tif
# Processando: MOSAICO_2015_tile_9617.tif
# Processando: MOSAICO_2015_tile_9618.tif
# Processando: MOSAICO_2015_tile_9619.tif
# Processando: MOSAICO_2015_tile_9620.tif
# Processando: MOSAICO_2015_tile_9621.tif
# Processando: MOSAICO_2015_tile_9622.tif
# Processando: MOSAICO_2015_tile_9623.tif
# Processando: MOSAICO_2015_tile_9624.tif
# Processando: MOSAICO_2015_tile_9625.tif
# Processando: MOSAICO_2015_tile_9626.tif
# Processando: MOSAICO_2015_tile_9627.tif
# Processando: MOSAICO_2015_tile_9628.tif
# Processando: MOSAICO_2015_tile_9629.tif
# Processando: MOSAICO_2015_tile_9630.tif
# Processando: MOSAICO_2015_tile_9631.tif
# Processando: MOSAICO_2015_tile_9632.tif
# Processando: MOSAICO_2015_tile_9633.tif
# Processando: MOSAICO_2015_tile_9634.tif
# Processando: MOSAICO_2015_tile_9635.tif
# Processando: MOSAICO_2015_tile_9636.tif
# Processando: MOSAICO_2015_tile_9637.tif
# Processando: MOSAICO_2015_tile_9638.tif
# Processando: MOSAICO_2015_tile_9639.tif
# Processando: MOSAICO_2015_tile_9640.tif
# Processando: MOSAICO_2015_tile_9641.tif
# Processando: MOSAICO_2015_tile_9642.tif
# Processando: MOSAICO_2015_tile_9643.tif
# Processando: MOSAICO_2015_tile_9644.tif
# Processando: MOSAICO_2015_tile_9645.tif
# Processando: MOSAICO_2015_tile_9646.tif
# Processando: MOSAICO_2015_tile_9647.tif
# Processando: MOSAICO_2015_tile_9648.tif
# Processando: MOSAICO_2015_tile_9649.tif
# Processando: MOSAICO_2015_tile_9650.tif
# Processando: MOSAICO_2015_tile_9651.tif
# Processando: MOSAICO_2015_tile_9652.tif
# Processando: MOSAICO_2015_tile_9653.tif
# Processando: MOSAICO_2015_tile_9654.tif
# Processando: MOSAICO_2015_tile_9655.tif
# Processando: MOSAICO_2015_tile_9656.tif
# Processando: MOSAICO_2015_tile_9657.tif
# Processando: MOSAICO_2015_tile_9658.tif
# Processando: MOSAICO_2015_tile_9659.tif
# Processando: MOSAICO_2015_tile_9660.tif
# Processando: MOSAICO_2015_tile_9661.tif
# Processando: MOSAICO_2015_tile_9662.tif
# Processando: MOSAICO_2015_tile_9663.tif
# Processando: MOSAICO_2015_tile_9664.tif
# Processando: MOSAICO_2015_tile_9665.tif
# Processando: MOSAICO_2015_tile_9666.tif
# Processando: MOSAICO_2015_tile_9667.tif
# Processando: MOSAICO_2015_tile_9668.tif
# Processando: MOSAICO_2015_tile_9669.tif
# Processando: MOSAICO_2015_tile_9670.tif
# Processando: MOSAICO_2015_tile_9671.tif
# Processando: MOSAICO_2015_tile_9672.tif
# Processando: MOSAICO_2015_tile_9673.tif
# Processando: MOSAICO_2015_tile_9674.tif
# Processando: MOSAICO_2015_tile_9675.tif
# Processando: MOSAICO_2015_tile_9676.tif
# Processando: MOSAICO_2015_tile_9677.tif
# Processando: MOSAICO_2015_tile_9678.tif
# Processando: MOSAICO_2015_tile_9679.tif
# Processando: MOSAICO_2015_tile_9680.tif
# Processando: MOSAICO_2015_tile_9681.tif
# Processando: MOSAICO_2015_tile_9682.tif
# Processando: MOSAICO_2015_tile_9683.tif
# Processando: MOSAICO_2015_tile_9684.tif
# Processando: MOSAICO_2015_tile_9685.tif
# Processando: MOSAICO_2015_tile_9686.tif
# Processando: MOSAICO_2015_tile_9687.tif
# Processando: MOSAICO_2015_tile_9688.tif
# Processando: MOSAICO_2015_tile_9689.tif
# Processando: MOSAICO_2015_tile_9690.tif
# Processando: MOSAICO_2015_tile_9691.tif
# Processando: MOSAICO_2015_tile_9692.tif
# Processando: MOSAICO_2015_tile_9693.tif
# Processando: MOSAICO_2015_tile_9694.tif
# Processando: MOSAICO_2015_tile_9695.tif
# Processando: MOSAICO_2015_tile_9696.tif
# Processando: MOSAICO_2015_tile_9697.tif
# Processando: MOSAICO_2015_tile_9698.tif
# Processando: MOSAICO_2015_tile_9699.tif
# Processando: MOSAICO_2015_tile_9700.tif
# Processando: MOSAICO_2015_tile_9701.tif
# Processando: MOSAICO_2015_tile_9702.tif
# Processando: MOSAICO_2015_tile_9703.tif
# Processando: MOSAICO_2015_tile_9704.tif
# Processando: MOSAICO_2015_tile_9705.tif
# Processando: MOSAICO_2015_tile_9706.tif
# Processando: MOSAICO_2015_tile_9707.tif
# Processando: MOSAICO_2015_tile_9708.tif
# Processando: MOSAICO_2015_tile_9709.tif
# Processando: MOSAICO_2015_tile_9710.tif
# Processando: MOSAICO_2015_tile_9711.tif
# Processando: MOSAICO_2015_tile_9712.tif
# Processando: MOSAICO_2015_tile_9713.tif
# Processando: MOSAICO_2015_tile_9714.tif
# Processando: MOSAICO_2015_tile_9715.tif
# Processando: MOSAICO_2015_tile_9716.tif
# Processando: MOSAICO_2015_tile_9717.tif
# Processando: MOSAICO_2015_tile_9718.tif
# Processando: MOSAICO_2015_tile_9719.tif
# Processando: MOSAICO_2015_tile_9720.tif
# Processando: MOSAICO_2015_tile_9721.tif
# Processando: MOSAICO_2015_tile_9722.tif
# Processando: MOSAICO_2015_tile_9723.tif
# Processando: MOSAICO_2015_tile_9724.tif
# Processando: MOSAICO_2015_tile_9725.tif
# Processando: MOSAICO_2015_tile_9726.tif
# Processando: MOSAICO_2015_tile_9727.tif
# Processando: MOSAICO_2015_tile_9728.tif
# Processando: MOSAICO_2015_tile_9729.tif
# Processando: MOSAICO_2015_tile_9730.tif
# Processando: MOSAICO_2015_tile_9731.tif
# Processando: MOSAICO_2015_tile_9732.tif
# Processando: MOSAICO_2015_tile_9733.tif
# Processando: MOSAICO_2015_tile_9734.tif
# Processando: MOSAICO_2015_tile_9735.tif
# Processando: MOSAICO_2015_tile_9736.tif
# Processando: MOSAICO_2015_tile_9737.tif
# Processando: MOSAICO_2015_tile_9738.tif
# Processando: MOSAICO_2015_tile_9739.tif
# Processando: MOSAICO_2015_tile_9740.tif
# Processando: MOSAICO_2015_tile_9741.tif
# Processando: MOSAICO_2015_tile_9742.tif
# Processando: MOSAICO_2015_tile_9743.tif
# Processando: MOSAICO_2015_tile_9744.tif
# Processando: MOSAICO_2015_tile_9745.tif
# Processando: MOSAICO_2015_tile_9746.tif
# Processando: MOSAICO_2015_tile_9827.tif
# Processando: MOSAICO_2015_tile_9828.tif
# Processando: MOSAICO_2015_tile_9829.tif
# Processando: MOSAICO_2015_tile_9830.tif
# Processando: MOSAICO_2015_tile_9831.tif
# Processando: MOSAICO_2015_tile_9832.tif
# Processando: MOSAICO_2015_tile_9833.tif
# Processando: MOSAICO_2015_tile_9834.tif
# Processando: MOSAICO_2015_tile_9835.tif
# Processando: MOSAICO_2015_tile_9836.tif
# Processando: MOSAICO_2015_tile_9837.tif
# Processando: MOSAICO_2015_tile_9838.tif
# Processando: MOSAICO_2015_tile_9839.tif
# Processando: MOSAICO_2015_tile_9840.tif
# Processando: MOSAICO_2015_tile_9841.tif
# Processando: MOSAICO_2015_tile_9842.tif
# Processando: MOSAICO_2015_tile_9843.tif
# Processando: MOSAICO_2015_tile_9844.tif
# Processando: MOSAICO_2015_tile_9845.tif
# Processando: MOSAICO_2015_tile_9846.tif
# Processando: MOSAICO_2015_tile_9847.tif
# Processando: MOSAICO_2015_tile_9848.tif
# Processando: MOSAICO_2015_tile_9849.tif
# Processando: MOSAICO_2015_tile_9850.tif
# Processando: MOSAICO_2015_tile_9851.tif
# Processando: MOSAICO_2015_tile_9852.tif
# Processando: MOSAICO_2015_tile_9853.tif
# Processando: MOSAICO_2015_tile_9854.tif
# Processando: MOSAICO_2015_tile_9855.tif
# Processando: MOSAICO_2015_tile_9856.tif
# Processando: MOSAICO_2015_tile_9857.tif
# Processando: MOSAICO_2015_tile_9858.tif
# Processando: MOSAICO_2015_tile_9859.tif
# Processando: MOSAICO_2015_tile_9860.tif
# Processando: MOSAICO_2015_tile_9861.tif
# Processando: MOSAICO_2015_tile_9862.tif
# Processando: MOSAICO_2015_tile_9863.tif
# Processando: MOSAICO_2015_tile_9864.tif
# Processando: MOSAICO_2015_tile_9865.tif
# Processando: MOSAICO_2015_tile_9866.tif
# Processando: MOSAICO_2015_tile_9867.tif
# Processando: MOSAICO_2015_tile_9868.tif
# Processando: MOSAICO_2015_tile_9869.tif
# Processando: MOSAICO_2015_tile_9870.tif
# Processando: MOSAICO_2015_tile_9871.tif
# Processando: MOSAICO_2015_tile_9872.tif
# Processando: MOSAICO_2015_tile_9873.tif
# Processando: MOSAICO_2015_tile_9874.tif
# Processando: MOSAICO_2015_tile_9875.tif
# Processando: MOSAICO_2015_tile_9876.tif
# Processando: MOSAICO_2015_tile_9877.tif
# Processando: MOSAICO_2015_tile_9878.tif
# Processando: MOSAICO_2015_tile_9879.tif
# Processando: MOSAICO_2015_tile_9880.tif
# Processando: MOSAICO_2015_tile_9881.tif
# Processando: MOSAICO_2015_tile_9882.tif
# Processando: MOSAICO_2015_tile_9883.tif
# Processando: MOSAICO_2015_tile_9884.tif
# Processando: MOSAICO_2015_tile_9885.tif
# Processando: MOSAICO_2015_tile_9886.tif
# Processando: MOSAICO_2015_tile_9887.tif
# Processando: MOSAICO_2015_tile_9888.tif
# Processando: MOSAICO_2015_tile_9889.tif
# Processando: MOSAICO_2015_tile_9890.tif
# Processando: MOSAICO_2015_tile_9891.tif
# Processando: MOSAICO_2015_tile_9892.tif
# Processando: MOSAICO_2015_tile_9893.tif
# Processando: MOSAICO_2015_tile_9894.tif
# Processando: MOSAICO_2015_tile_9895.tif
# Processando: MOSAICO_2015_tile_9896.tif
# Processando: MOSAICO_2015_tile_9897.tif
# Processando: MOSAICO_2015_tile_9898.tif
# Processando: MOSAICO_2015_tile_9899.tif
# Processando: MOSAICO_2015_tile_9900.tif
# Processando: MOSAICO_2015_tile_9901.tif
# Processando: MOSAICO_2015_tile_9902.tif
# Processando: MOSAICO_2015_tile_9903.tif
# Processando: MOSAICO_2015_tile_9904.tif
# Processando: MOSAICO_2015_tile_9905.tif
# Processando: MOSAICO_2015_tile_9906.tif
# Processando: MOSAICO_2015_tile_9907.tif
# Processando: MOSAICO_2015_tile_9908.tif
# Processando: MOSAICO_2015_tile_9909.tif
# Processando: MOSAICO_2015_tile_9910.tif
# Processando: MOSAICO_2015_tile_9911.tif
# Processando: MOSAICO_2015_tile_9912.tif
# Processando: MOSAICO_2015_tile_9913.tif
# Processando: MOSAICO_2015_tile_9914.tif
# Processando: MOSAICO_2015_tile_9915.tif
# Processando: MOSAICO_2015_tile_9916.tif
# Processando: MOSAICO_2015_tile_9917.tif
# Processando: MOSAICO_2015_tile_9918.tif
# Processando: MOSAICO_2015_tile_9919.tif
# Processando: MOSAICO_2015_tile_9920.tif
# Processando: MOSAICO_2015_tile_9921.tif
# Processando: MOSAICO_2015_tile_9922.tif
# Processando: MOSAICO_2015_tile_9923.tif
# Processando: MOSAICO_2015_tile_9924.tif
# Processando: MOSAICO_2015_tile_9925.tif
# Processando: MOSAICO_2015_tile_9926.tif
# Processando: MOSAICO_2015_tile_9927.tif
# Processando: MOSAICO_2015_tile_9928.tif
# Processando: MOSAICO_2015_tile_9929.tif
# Processando: MOSAICO_2015_tile_9930.tif
# Processando: MOSAICO_2015_tile_9931.tif
# Processando: MOSAICO_2015_tile_9932.tif
# Processando: MOSAICO_2015_tile_9933.tif
# Processando: MOSAICO_2015_tile_9934.tif
# Processando: MOSAICO_2015_tile_9935.tif
# Processando: MOSAICO_2015_tile_9936.tif
# Processando: MOSAICO_2015_tile_9937.tif
# Processando: MOSAICO_2015_tile_9938.tif
# Processando: MOSAICO_2015_tile_9939.tif
# Processando: MOSAICO_2015_tile_994.tif
# Processando: MOSAICO_2015_tile_9940.tif
# Processando: MOSAICO_2015_tile_9941.tif
# Processando: MOSAICO_2015_tile_9942.tif
# Processando: MOSAICO_2015_tile_9943.tif
# Processando: MOSAICO_2015_tile_9944.tif
# Processando: MOSAICO_2015_tile_9945.tif
# Processando: MOSAICO_2015_tile_9946.tif
# Processando: MOSAICO_2015_tile_9947.tif
# Processando: MOSAICO_2015_tile_9948.tif
# Processando: MOSAICO_2015_tile_9949.tif
# Processando: MOSAICO_2015_tile_995.tif
# Processando: MOSAICO_2015_tile_9950.tif
# Processando: MOSAICO_2015_tile_9951.tif
# Processando: MOSAICO_2015_tile_9952.tif
# Processando: MOSAICO_2015_tile_9953.tif
# Processando: MOSAICO_2015_tile_9954.tif
# Processando: MOSAICO_2015_tile_9955.tif
# Processando: MOSAICO_2015_tile_9956.tif
# Processando: MOSAICO_2015_tile_9957.tif
# Processando: MOSAICO_2015_tile_9958.tif
# Processando: MOSAICO_2015_tile_9959.tif
# Processando: MOSAICO_2015_tile_996.tif
# Processando: MOSAICO_2015_tile_9960.tif
# Processando: MOSAICO_2015_tile_9961.tif
# Processando: MOSAICO_2015_tile_9962.tif
# Processando: MOSAICO_2015_tile_9963.tif
# Processando: MOSAICO_2015_tile_9964.tif
# Processando: MOSAICO_2015_tile_9965.tif
# Processando: MOSAICO_2015_tile_9966.tif
# Processando: MOSAICO_2015_tile_9967.tif
# Processando: MOSAICO_2015_tile_9968.tif
# Processando: MOSAICO_2015_tile_997.tif
# Processando: MOSAICO_2015_tile_998.tif
# Processando: MOSAICO_2015_tile_999.tif
# Inferência concluída! Arquivos em grayscale salvos em: INFERENCIA/
